# %%
import numpy as np
import pandas as pd
# %matplotlib widget
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
from scipy import stats

# %% [markdown]
# # load and wrangle

# %%
dwellT_nfixF = True   # shouldn't use both dwell and n/p fix because highly collinear
HnT_dF = True   

file_loc = "C:\\Users\\Luke\\Documents\\AlloEye\\data\\feature_saves\\all_conds.csv"
df = pd.read_csv(file_loc)

# wrangle some columns
def drop_col_with(df, string):
    for col in df.columns:
        if string in col:
            df = df.drop([col], axis=1)
    return df 

df = drop_col_with(df, 'Unnamed')
print(df.shape)
df = df[df['NP test date'] != 'EXCLUDED']
print(df.shape)
drop_cols = ['n_correct', 'n_trials', 'biomarkers', 'pupil_diam_centre_enc', 'pupil_diam_centre_ret',
            'pupil_diam_spread_ret', 'pupil_diam_spread_enc',
            'VR test date', 'VR tester', 'NP test date', 'NP tester', 'english',
             'handedness', 'Rey Immediate']
df = df.drop(drop_cols, axis=1)

# drop entropy 
e_drop = 'hd' if HnT_dF else 'hn'
df = drop_col_with(df, e_drop)

# remove sacc for now
df = drop_col_with(df, 'sacc')

# # remove velocity for now
df = drop_col_with(df, 'velocity_std')

# remove drop out for now
df = drop_col_with(df, 'drop_out')

# dwell comparison
# df['dwell_MOvsSOs_enc'] = df['dwell_obj1_enc'] - df['dwell_obj2_enc'] - df['dwell_obj3_enc'] - df['dwell_obj4_enc']
df['dwell_MO-SOs_ret'] = df['dwell_obj1_ret'] - df['dwell_obj2_ret'] - df['dwell_obj3_ret'] - df['dwell_obj4_ret']
# df['dwell_MOvsSOs_diff'] = df['dwell_MOvsSOs_ret'] - df['dwell_MOvsSOs_enc']
# df = df.drop(['dwell_MOvsSOs_enc'], axis=1)
# df['dwell_MOret_v_Os_er'] = df['dwell_MO-SOs_ret'] - df['dwell_obj1_enc'] - df['dwell_obj2_enc'] - df['dwell_obj3_enc'] - df['dwell_obj4_enc']
# df['dwell_MO-meanSOs_enc'] = df['dwell_obj1_enc'] - np.nanmean(df.loc[:, ['dwell_obj2_enc', 'dwell_obj3_enc', 'dwell_obj4_enc']], axis=1)
# df['dwell_MO-meanSOs_ret'] = df['dwell_obj1_ret'] - np.nanmean(df.loc[:, ['dwell_obj2_ret', 'dwell_obj3_ret', 'dwell_obj4_ret']], axis=1)
# df['dwell_MO-meanSOs_diff'] = df['dwell_MO-meanSOs_ret'] - df['dwell_MO-meanSOs_enc']
# df['dwell_MO-table_ret'] = df['dwell_obj1_ret'] - df['dwell_table_ret']
# df['dwell_Os_v_table_ret'] = df['dwell_obj1_ret'] + df['dwell_obj2_ret'] + df['dwell_obj3_ret'] + df['dwell_obj4_ret'] - df['dwell_table_ret']
# df['dwell_Os_v_table_diff'] = df['dwell_Os_v_table_ret'] - (df['dwell_obj1_enc'] + df['dwell_obj2_enc'] + df['dwell_obj3_enc'] + df['dwell_obj4_enc'] - df['dwell_table_enc'])

# drop obj2-4 cols
for col in df.columns:
    if'obj' in col:
        if '2' in col or '3' in col or '4' in col:
            df = df.drop([col], axis=1)

# p fixations - NEED TO DEAL WITH INFINITIES CAUSED BY DIFF - DIVIDING BY 0
for col in df.columns:
    if 'n_fix' in col and 'total' not in col and 'diff' not in col:
        rem = col.split('n_fix')[-1]
        view = rem.split('_')[-1]
        new_col = 'p_fix'+rem
        total = 'n_fix_total_'+view
        df[new_col] = df[col] / df[total]
        df = df.drop([col], axis=1)
for col in df.columns:
    if 'n_fix' in col and 'total' in col:
        df = df.drop([col], axis=1)


# dwell time as proportion
for col in df.columns:
    if 'dwell' in col and 'total' not in col:
        if 'ret' in col:
            df[col] /= df['dwell_total_ret']
        else:
            df[col] /= df['dwell_total_enc']
df = df.drop_col_with(df, 'dwell_total')

# sort 4MT
first_col = 0
col_saved = False
for col in df.columns:
    if '4MT' in col:
        nas = pd.isna(df[col])
        # print(sum(nas))
        if 'RT' not in col:
            df[col] = np.where(df[col] == 'CORRECT', 1, 0)
            if col_saved is False:
                first_col = df.columns.get_loc(col)
                col_saved = True
        df[col][nas] = np.nan
df['4MT'] = df.iloc[:, first_col:first_col+15].sum(axis=1)
df = drop_col_with(df, '4MT_T')

# neuropsych wrangling
# df['FCSRT_FR_I'] = df['FCSRT T1 FR'] + df['FCSRT T2 FR'] + df['FCSRT T3 FR']
# df['FCSRT_TR_I'] = df['FCSRT T1 TR'] + df['FCSRT T2 TR'] + df['FCSRT T3 TR']
df = drop_col_with(df, 'FCSRT T')

# choose either dwell or p fix
if dwellT_nfixF is True:
    df = drop_col_with(df, 'fix')
else:
    df = drop_col_with(df, 'dwell')

display(df.head(10).style)

# descriptive statistics

# remove exclusions
print(df.shape)
control_ace_cutoff = (((df['ACE-III_total'] > 88) | pd.isna(df['ACE-III_total']))
                      &  (df['group'] != 'P')) | (df['group'] == 'P')
yoe_cutoff = (((df['yoe'] <= 17) | pd.isna(df['yoe']))
                      &  (df['group'] != 'P')) | (df['group'] == 'P')
df = df[control_ace_cutoff]
df = df[yoe_cutoff]

display(df[df.group == 'O'].style)

df['f_bool'] = np.where(df.sex == 'f', 1, 0)
groupby_group = df.groupby(by='group')
ds = pd.DataFrame()
ds['n'] =  groupby_group.count().ppt_id
ds['female_p'] =  groupby_group.sum().f_bool / groupby_group.count().ppt_id
mean_cols = ['age', 'yoe','NART']
ace_cols = ['ACE-III_attention', 'ACE-III_verbalfluency', 
             'ACE-III_language', 'ACE-III_visuospatial',
             'ACE-III_perceptual', 'ACE-III_memory', 'ACE-III_total']
for col in mean_cols:
    ds[col] = groupby_group.agg({col: np.nanmean})




display(ds.style.format(precision=2))

n_cols = len(ds.columns)


fig, axes = plt.subplots(1, n_cols, figsize=(15, 3), dpi=150)
plt.subplots_adjust(left=0.1,
                    bottom=0.1,
                    right=0.9,
                    top=0.9,
                    wspace=0.6,
                    hspace=0.6)
g = ['Y', 'O', 'P']
x = ["HY", "HO", "MCI"]
for i in range(n_cols):
    feat = ds.columns[i]
    y = [ds[feat][2], ds[feat][0], ds[feat][1]]
    axes[i].bar(x, y)  
    if i > 1:  # skip n and p_female
        # print(df[feat])
        # err = [stats.sem(df[df.group == g[j]][feat]) for j in range(len(x))]
        err = [np.nanstd(df[df.group == g[j]][feat]) for j in range(len(x))]
        axes[i].errorbar(x, y, yerr=err, fmt='none', color="r")
          
    axes[i].set_title(feat)
    
drop_cols = mean_cols.extend(['sex', 'f_bool'])
df = df.drop(mean_cols, axis=1)
df = df.drop(ace_cols, axis=1)
# Out:
# (59, 182)
# (58, 182)
# C:\Users\Luke\AppData\Local\Temp\ipykernel_2548\3099092068.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col][nas] = np.nan
# <style type="text/css">
# </style>
# <table id="T_9b5f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b5f9_level0_col0" class="col_heading level0 col0" >ppt_id</th>
#       <th id="T_9b5f9_level0_col1" class="col_heading level0 col1" >p_correct</th>
#       <th id="T_9b5f9_level0_col2" class="col_heading level0 col2" >mean_confidence</th>
#       <th id="T_9b5f9_level0_col3" class="col_heading level0 col3" >hn_enc</th>
#       <th id="T_9b5f9_level0_col4" class="col_heading level0 col4" >dwell_obj1_enc</th>
#       <th id="T_9b5f9_level0_col5" class="col_heading level0 col5" >dwell_pp_enc</th>
#       <th id="T_9b5f9_level0_col6" class="col_heading level0 col6" >dwell_table_enc</th>
#       <th id="T_9b5f9_level0_col7" class="col_heading level0 col7" >dwell_other_enc</th>
#       <th id="T_9b5f9_level0_col8" class="col_heading level0 col8" >t_first_array_enc</th>
#       <th id="T_9b5f9_level0_col9" class="col_heading level0 col9" >t_first_obj1_enc</th>
#       <th id="T_9b5f9_level0_col10" class="col_heading level0 col10" >dispersion_mean_enc</th>
#       <th id="T_9b5f9_level0_col11" class="col_heading level0 col11" >velocity_mean_total_enc</th>
#       <th id="T_9b5f9_level0_col12" class="col_heading level0 col12" >n_blinks_enc</th>
#       <th id="T_9b5f9_level0_col13" class="col_heading level0 col13" >p_trackloss_enc</th>
#       <th id="T_9b5f9_level0_col14" class="col_heading level0 col14" >hn_ret</th>
#       <th id="T_9b5f9_level0_col15" class="col_heading level0 col15" >dwell_obj1_ret</th>
#       <th id="T_9b5f9_level0_col16" class="col_heading level0 col16" >dwell_pp_ret</th>
#       <th id="T_9b5f9_level0_col17" class="col_heading level0 col17" >dwell_table_ret</th>
#       <th id="T_9b5f9_level0_col18" class="col_heading level0 col18" >dwell_other_ret</th>
#       <th id="T_9b5f9_level0_col19" class="col_heading level0 col19" >t_first_array_ret</th>
#       <th id="T_9b5f9_level0_col20" class="col_heading level0 col20" >t_first_obj1_ret</th>
#       <th id="T_9b5f9_level0_col21" class="col_heading level0 col21" >dispersion_mean_ret</th>
#       <th id="T_9b5f9_level0_col22" class="col_heading level0 col22" >velocity_mean_total_ret</th>
#       <th id="T_9b5f9_level0_col23" class="col_heading level0 col23" >n_blinks_ret</th>
#       <th id="T_9b5f9_level0_col24" class="col_heading level0 col24" >p_trackloss_ret</th>
#       <th id="T_9b5f9_level0_col25" class="col_heading level0 col25" >hn_diff</th>
#       <th id="T_9b5f9_level0_col26" class="col_heading level0 col26" >dwell_total_diff</th>
#       <th id="T_9b5f9_level0_col27" class="col_heading level0 col27" >dwell_obj1_diff</th>
#       <th id="T_9b5f9_level0_col28" class="col_heading level0 col28" >dwell_pp_diff</th>
#       <th id="T_9b5f9_level0_col29" class="col_heading level0 col29" >dwell_table_diff</th>
#       <th id="T_9b5f9_level0_col30" class="col_heading level0 col30" >dwell_other_diff</th>
#       <th id="T_9b5f9_level0_col31" class="col_heading level0 col31" >t_first_array_diff</th>
#       <th id="T_9b5f9_level0_col32" class="col_heading level0 col32" >t_first_obj1_diff</th>
#       <th id="T_9b5f9_level0_col33" class="col_heading level0 col33" >dispersion_mean_diff</th>
#       <th id="T_9b5f9_level0_col34" class="col_heading level0 col34" >velocity_mean_total_diff</th>
#       <th id="T_9b5f9_level0_col35" class="col_heading level0 col35" >pupil_diam_centre_diff</th>
#       <th id="T_9b5f9_level0_col36" class="col_heading level0 col36" >pupil_diam_spread_diff</th>
#       <th id="T_9b5f9_level0_col37" class="col_heading level0 col37" >n_blinks_diff</th>
#       <th id="T_9b5f9_level0_col38" class="col_heading level0 col38" >p_trackloss_diff</th>
#       <th id="T_9b5f9_level0_col39" class="col_heading level0 col39" >d_kl</th>
#       <th id="T_9b5f9_level0_col40" class="col_heading level0 col40" >ea_td</th>
#       <th id="T_9b5f9_level0_col41" class="col_heading level0 col41" >group</th>
#       <th id="T_9b5f9_level0_col42" class="col_heading level0 col42" >age</th>
#       <th id="T_9b5f9_level0_col43" class="col_heading level0 col43" >sex</th>
#       <th id="T_9b5f9_level0_col44" class="col_heading level0 col44" >yoe</th>
#       <th id="T_9b5f9_level0_col45" class="col_heading level0 col45" >NART</th>
#       <th id="T_9b5f9_level0_col46" class="col_heading level0 col46" >Ravens</th>
#       <th id="T_9b5f9_level0_col47" class="col_heading level0 col47" >Camden</th>
#       <th id="T_9b5f9_level0_col48" class="col_heading level0 col48" >FCSRT D FR</th>
#       <th id="T_9b5f9_level0_col49" class="col_heading level0 col49" >FCSRT D TR</th>
#       <th id="T_9b5f9_level0_col50" class="col_heading level0 col50" >TMT</th>
#       <th id="T_9b5f9_level0_col51" class="col_heading level0 col51" >Rey Copy</th>
#       <th id="T_9b5f9_level0_col52" class="col_heading level0 col52" >Rey Delayed</th>
#       <th id="T_9b5f9_level0_col53" class="col_heading level0 col53" >DST</th>
#       <th id="T_9b5f9_level0_col54" class="col_heading level0 col54" >ACE-III_attention</th>
#       <th id="T_9b5f9_level0_col55" class="col_heading level0 col55" >ACE-III_verbalfluency</th>
#       <th id="T_9b5f9_level0_col56" class="col_heading level0 col56" >ACE-III_memory</th>
#       <th id="T_9b5f9_level0_col57" class="col_heading level0 col57" >ACE-III_language</th>
#       <th id="T_9b5f9_level0_col58" class="col_heading level0 col58" >ACE-III_visuospatial</th>
#       <th id="T_9b5f9_level0_col59" class="col_heading level0 col59" >ACE-III_perceptual</th>
#       <th id="T_9b5f9_level0_col60" class="col_heading level0 col60" >ACE-III_total</th>
#       <th id="T_9b5f9_level0_col61" class="col_heading level0 col61" >dwell_MO-SOs_ret</th>
#       <th id="T_9b5f9_level0_col62" class="col_heading level0 col62" >4MT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b5f9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9b5f9_row0_col0" class="data row0 col0" >18</td>
#       <td id="T_9b5f9_row0_col1" class="data row0 col1" >0.648148</td>
#       <td id="T_9b5f9_row0_col2" class="data row0 col2" >6.759259</td>
#       <td id="T_9b5f9_row0_col3" class="data row0 col3" >0.206235</td>
#       <td id="T_9b5f9_row0_col4" class="data row0 col4" >0.141605</td>
#       <td id="T_9b5f9_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_9b5f9_row0_col6" class="data row0 col6" >0.259154</td>
#       <td id="T_9b5f9_row0_col7" class="data row0 col7" >0.080244</td>
#       <td id="T_9b5f9_row0_col8" class="data row0 col8" >750.191468</td>
#       <td id="T_9b5f9_row0_col9" class="data row0 col9" >4639.593254</td>
#       <td id="T_9b5f9_row0_col10" class="data row0 col10" >0.212938</td>
#       <td id="T_9b5f9_row0_col11" class="data row0 col11" >0.006887</td>
#       <td id="T_9b5f9_row0_col12" class="data row0 col12" >4.311508</td>
#       <td id="T_9b5f9_row0_col13" class="data row0 col13" >0.589032</td>
#       <td id="T_9b5f9_row0_col14" class="data row0 col14" >0.474456</td>
#       <td id="T_9b5f9_row0_col15" class="data row0 col15" >0.265205</td>
#       <td id="T_9b5f9_row0_col16" class="data row0 col16" >0.001418</td>
#       <td id="T_9b5f9_row0_col17" class="data row0 col17" >0.151838</td>
#       <td id="T_9b5f9_row0_col18" class="data row0 col18" >0.039600</td>
#       <td id="T_9b5f9_row0_col19" class="data row0 col19" >308.678571</td>
#       <td id="T_9b5f9_row0_col20" class="data row0 col20" >2440.849206</td>
#       <td id="T_9b5f9_row0_col21" class="data row0 col21" >0.049546</td>
#       <td id="T_9b5f9_row0_col22" class="data row0 col22" >0.005823</td>
#       <td id="T_9b5f9_row0_col23" class="data row0 col23" >3.484127</td>
#       <td id="T_9b5f9_row0_col24" class="data row0 col24" >0.233848</td>
#       <td id="T_9b5f9_row0_col25" class="data row0 col25" >0.270124</td>
#       <td id="T_9b5f9_row0_col26" class="data row0 col26" >-0.039617</td>
#       <td id="T_9b5f9_row0_col27" class="data row0 col27" >0.122937</td>
#       <td id="T_9b5f9_row0_col28" class="data row0 col28" >0.001418</td>
#       <td id="T_9b5f9_row0_col29" class="data row0 col29" >-0.106273</td>
#       <td
# (58, 63)
# C:\Users\Luke\AppData\Local\Temp\ipykernel_2548\3099092068.py:114: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df[yoe_cutoff]
# <style type="text/css">
# </style>
# <table id="T_5ad80">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ad80_level0_col0" class="col_heading level0 col0" >ppt_id</th>
#       <th id="T_5ad80_level0_col1" class="col_heading level0 col1" >p_correct</th>
#       <th id="T_5ad80_level0_col2" class="col_heading level0 col2" >mean_confidence</th>
#       <th id="T_5ad80_level0_col3" class="col_heading level0 col3" >hn_enc</th>
#       <th id="T_5ad80_level0_col4" class="col_heading level0 col4" >dwell_obj1_enc</th>
#       <th id="T_5ad80_level0_col5" class="col_heading level0 col5" >dwell_pp_enc</th>
#       <th id="T_5ad80_level0_col6" class="col_heading level0 col6" >dwell_table_enc</th>
#       <th id="T_5ad80_level0_col7" class="col_heading level0 col7" >dwell_other_enc</th>
#       <th id="T_5ad80_level0_col8" class="col_heading level0 col8" >t_first_array_enc</th>
#       <th id="T_5ad80_level0_col9" class="col_heading level0 col9" >t_first_obj1_enc</th>
#       <th id="T_5ad80_level0_col10" class="col_heading level0 col10" >dispersion_mean_enc</th>
#       <th id="T_5ad80_level0_col11" class="col_heading level0 col11" >velocity_mean_total_enc</th>
#       <th id="T_5ad80_level0_col12" class="col_heading level0 col12" >n_blinks_enc</th>
#       <th id="T_5ad80_level0_col13" class="col_heading level0 col13" >p_trackloss_enc</th>
#       <th id="T_5ad80_level0_col14" class="col_heading level0 col14" >hn_ret</th>
#       <th id="T_5ad80_level0_col15" class="col_heading level0 col15" >dwell_obj1_ret</th>
#       <th id="T_5ad80_level0_col16" class="col_heading level0 col16" >dwell_pp_ret</th>
#       <th id="T_5ad80_level0_col17" class="col_heading level0 col17" >dwell_table_ret</th>
#       <th id="T_5ad80_level0_col18" class="col_heading level0 col18" >dwell_other_ret</th>
#       <th id="T_5ad80_level0_col19" class="col_heading level0 col19" >t_first_array_ret</th>
#       <th id="T_5ad80_level0_col20" class="col_heading level0 col20" >t_first_obj1_ret</th>
#       <th id="T_5ad80_level0_col21" class="col_heading level0 col21" >dispersion_mean_ret</th>
#       <th id="T_5ad80_level0_col22" class="col_heading level0 col22" >velocity_mean_total_ret</th>
#       <th id="T_5ad80_level0_col23" class="col_heading level0 col23" >n_blinks_ret</th>
#       <th id="T_5ad80_level0_col24" class="col_heading level0 col24" >p_trackloss_ret</th>
#       <th id="T_5ad80_level0_col25" class="col_heading level0 col25" >hn_diff</th>
#       <th id="T_5ad80_level0_col26" class="col_heading level0 col26" >dwell_total_diff</th>
#       <th id="T_5ad80_level0_col27" class="col_heading level0 col27" >dwell_obj1_diff</th>
#       <th id="T_5ad80_level0_col28" class="col_heading level0 col28" >dwell_pp_diff</th>
#       <th id="T_5ad80_level0_col29" class="col_heading level0 col29" >dwell_table_diff</th>
#       <th id="T_5ad80_level0_col30" class="col_heading level0 col30" >dwell_other_diff</th>
#       <th id="T_5ad80_level0_col31" class="col_heading level0 col31" >t_first_array_diff</th>
#       <th id="T_5ad80_level0_col32" class="col_heading level0 col32" >t_first_obj1_diff</th>
#       <th id="T_5ad80_level0_col33" class="col_heading level0 col33" >dispersion_mean_diff</th>
#       <th id="T_5ad80_level0_col34" class="col_heading level0 col34" >velocity_mean_total_diff</th>
#       <th id="T_5ad80_level0_col35" class="col_heading level0 col35" >pupil_diam_centre_diff</th>
#       <th id="T_5ad80_level0_col36" class="col_heading level0 col36" >pupil_diam_spread_diff</th>
#       <th id="T_5ad80_level0_col37" class="col_heading level0 col37" >n_blinks_diff</th>
#       <th id="T_5ad80_level0_col38" class="col_heading level0 col38" >p_trackloss_diff</th>
#       <th id="T_5ad80_level0_col39" class="col_heading level0 col39" >d_kl</th>
#       <th id="T_5ad80_level0_col40" class="col_heading level0 col40" >ea_td</th>
#       <th id="T_5ad80_level0_col41" class="col_heading level0 col41" >group</th>
#       <th id="T_5ad80_level0_col42" class="col_heading level0 col42" >age</th>
#       <th id="T_5ad80_level0_col43" class="col_heading level0 col43" >sex</th>
#       <th id="T_5ad80_level0_col44" class="col_heading level0 col44" >yoe</th>
#       <th id="T_5ad80_level0_col45" class="col_heading level0 col45" >NART</th>
#       <th id="T_5ad80_level0_col46" class="col_heading level0 col46" >Ravens</th>
#       <th id="T_5ad80_level0_col47" class="col_heading level0 col47" >Camden</th>
#       <th id="T_5ad80_level0_col48" class="col_heading level0 col48" >FCSRT D FR</th>
#       <th id="T_5ad80_level0_col49" class="col_heading level0 col49" >FCSRT D TR</th>
#       <th id="T_5ad80_level0_col50" class="col_heading level0 col50" >TMT</th>
#       <th id="T_5ad80_level0_col51" class="col_heading level0 col51" >Rey Copy</th>
#       <th id="T_5ad80_level0_col52" class="col_heading level0 col52" >Rey Delayed</th>
#       <th id="T_5ad80_level0_col53" class="col_heading level0 col53" >DST</th>
#       <th id="T_5ad80_level0_col54" class="col_heading level0 col54" >ACE-III_attention</th>
#       <th id="T_5ad80_level0_col55" class="col_heading level0 col55" >ACE-III_verbalfluency</th>
#       <th id="T_5ad80_level0_col56" class="col_heading level0 col56" >ACE-III_memory</th>
#       <th id="T_5ad80_level0_col57" class="col_heading level0 col57" >ACE-III_language</th>
#       <th id="T_5ad80_level0_col58" class="col_heading level0 col58" >ACE-III_visuospatial</th>
#       <th id="T_5ad80_level0_col59" class="col_heading level0 col59" >ACE-III_perceptual</th>
#       <th id="T_5ad80_level0_col60" class="col_heading level0 col60" >ACE-III_total</th>
#       <th id="T_5ad80_level0_col61" class="col_heading level0 col61" >dwell_MO-SOs_ret</th>
#       <th id="T_5ad80_level0_col62" class="col_heading level0 col62" >4MT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ad80_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5ad80_row0_col0" class="data row0 col0" >18</td>
#       <td id="T_5ad80_row0_col1" class="data row0 col1" >0.648148</td>
#       <td id="T_5ad80_row0_col2" class="data row0 col2" >6.759259</td>
#       <td id="T_5ad80_row0_col3" class="data row0 col3" >0.206235</td>
#       <td id="T_5ad80_row0_col4" class="data row0 col4" >0.141605</td>
#       <td id="T_5ad80_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_5ad80_row0_col6" class="data row0 col6" >0.259154</td>
#       <td id="T_5ad80_row0_col7" class="data row0 col7" >0.080244</td>
#       <td id="T_5ad80_row0_col8" class="data row0 col8" >750.191468</td>
#       <td id="T_5ad80_row0_col9" class="data row0 col9" >4639.593254</td>
#       <td id="T_5ad80_row0_col10" class="data row0 col10" >0.212938</td>
#       <td id="T_5ad80_row0_col11" class="data row0 col11" >0.006887</td>
#       <td id="T_5ad80_row0_col12" class="data row0 col12" >4.311508</td>
#       <td id="T_5ad80_row0_col13" class="data row0 col13" >0.589032</td>
#       <td id="T_5ad80_row0_col14" class="data row0 col14" >0.474456</td>
#       <td id="T_5ad80_row0_col15" class="data row0 col15" >0.265205</td>
#       <td id="T_5ad80_row0_col16" class="data row0 col16" >0.001418</td>
#       <td id="T_5ad80_row0_col17" class="data row0 col17" >0.151838</td>
#       <td id="T_5ad80_row0_col18" class="data row0 col18" >0.039600</td>
#       <td id="T_5ad80_row0_col19" class="data row0 col19" >308.678571</td>
#       <td id="T_5ad80_row0_col20" class="data row0 col20" >2440.849206</td>
#       <td id="T_5ad80_row0_col21" class="data row0 col21" >0.049546</td>
#       <td id="T_5ad80_row0_col22" class="data row0 col22" >0.005823</td>
#       <td id="T_5ad80_row0_col23" class="data row0 col23" >3.484127</td>
#       <td id="T_5ad80_row0_col24" class="data row0 col24" >0.233848</td>
#       <td id="T_5ad80_row0_col25" class="data row0 col25" >0.270124</td>
#       <td id="T_5ad80_row0_col26" class="data row0 col26" >-0.039617</td>
#       <td id="T_5ad80_row0_col27" class="data row0 col27" >0.122937</td>
#       <td id="T_5ad80_row0_col28" class="data row0 col28" >0.001418</td>
#       <td id="T_5ad80_row0_col29" class="data row0 col29" >-0.106273</td>
#       <td
# <style type="text/css">
# </style>
# <table id="T_bc197">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc197_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_bc197_level0_col1" class="col_heading level0 col1" >female_p</th>
#       <th id="T_bc197_level0_col2" class="col_heading level0 col2" >age</th>
#       <th id="T_bc197_level0_col3" class="col_heading level0 col3" >yoe</th>
#       <th id="T_bc197_level0_col4" class="col_heading level0 col4" >NART</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc197_level0_row0" class="row_heading level0 row0" >O</th>
#       <td id="T_bc197_row0_col0" class="data row0 col0" >18</td>
#       <td id="T_bc197_row0_col1" class="data row0 col1" >0.50</td>
#       <td id="T_bc197_row0_col2" class="data row0 col2" >73.25</td>
#       <td id="T_bc197_row0_col3" class="data row0 col3" >15.00</td>
#       <td id="T_bc197_row0_col4" class="data row0 col4" >40.25</td>
#     </tr>
#     <tr>
#       <th id="T_bc197_level0_row1" class="row_heading level0 row1" >P</th>
#       <td id="T_bc197_row1_col0" class="data row1 col0" >10</td>
#       <td id="T_bc197_row1_col1" class="data row1 col1" >0.20</td>
#       <td id="T_bc197_row1_col2" class="data row1 col2" >68.33</td>
#       <td id="T_bc197_row1_col3" class="data row1 col3" >14.50</td>
#       <td id="T_bc197_row1_col4" class="data row1 col4" >40.78</td>
#     </tr>
#     <tr>
#       <th id="T_bc197_level0_row2" class="row_heading level0 row2" >Y</th>
#       <td id="T_bc197_row2_col0" class="data row2 col0" >19</td>
#       <td id="T_bc197_row2_col1" class="data row2 col1" >0.84</td>
#       <td id="T_bc197_row2_col2" class="data row2 col2" >23.19</td>
#       <td id="T_bc197_row2_col3" class="data row2 col3" >15.61</td>
#       <td id="T_bc197_row2_col4" class="data row2 col4" >31.42</td>
#     </tr>
#   </tbody>
# </table>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# descriptive statistics

# remove exclusions
print(df.shape)
control_ace_cutoff = (df['ACE-III_total'] > 88) & (df['group'] != 'P')
df = df[control_ace_cutoff]
print(df.shape)
df['f_bool'] = np.where(df.sex == 'f', 1, 0)
groupby_group = df.groupby(by='group')
ds = pd.DataFrame()
ds['n'] =  groupby_group.count().ppt_id
ds['female_p'] =  groupby_group.sum().f_bool / groupby_group.count().ppt_id
mean_cols = ['age', 'yoe', 'Ravens', 'NART']
ace_cols = ['ACE-III_attention', 'ACE-III_verbalfluency', 
             'ACE-III_language', 'ACE-III_visuospatial',
             'ACE-III_perceptual', 'ACE-III_memory', 'ACE-III_total']
for col in mean_cols:
    ds[col] = groupby_group.agg({col: np.nanmean})


drop_cols = mean_cols.extend(['sex', 'f_bool'])
df = df.drop(mean_cols, axis=1)
df = df.drop(ace_cols, axis=1)

display(ds.style.format(precision=2))

n_cols = len(ds.columns)


fig, axes = plt.subplots(1, n_cols, figsize=(15, 3), dpi=150)
plt.subplots_adjust(left=0.1,
                    bottom=0.1,
                    right=0.9,
                    top=0.9,
                    wspace=0.6,
                    hspace=0.6)
x = ["HY", "HO", "MCI"]
for i in range(n_cols):
    feat = ds.columns[i]
    y = [ds[feat][2], ds[feat][0], ds[feat][1]]
    axes[i].bar(x, y)
    axes[i].set_title(feat)
# Out:
# (1, 51)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\alloeyepy\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~\anaconda3\envs\alloeyepy\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\alloeyepy\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ACE-III_total'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [11], in <cell line: 5>()
#       1 # descriptive statistics
#       2
#       3 # remove exclusions
#       4 print(df.shape)
# ----> 5 df = df[not ((df['ACE-III_total'] <= 88) & (df['group'] == 'O'))]
#       6 print(df.shape)
#       7 df['f_bool'] = np.where(df.sex == 'f', 1, 0)
#
# File ~\anaconda3\envs\alloeyepy\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\envs\alloeyepy\lib\site-packages\pandas\core\indexes\base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'ACE-III_total'

# %%
# more wrangling

from sklearn import preprocessing

X = df.drop(['ppt_id'], axis=1).dropna(thresh=10).reset_index(drop=True)

replace_map = {'P': 0, 'O': 1, 'Y': 2}
X['group'] = X['group'].replace(replace_map)

y = X['group']
X = X.drop(['group'], axis=1)
X_cols = X.columns
# X_cols = X.columns

# replace with multiple imputation at some point
for col in X.columns:
    # print(col)
    X[col] = X[col].fillna(np.nanmean(X[col]))
    
Xs = preprocessing.StandardScaler().fit(X).transform(X)
Xs_df = pd.DataFrame(Xs, columns=X_cols)
Xs_df['group'] = y
Xsg = Xs_df.groupby(by='group').mean()
Xs_df = Xs_df.drop(['group'], axis=1)
# convert to absolute group differences
for col in Xsg.columns:
    Xsg[col][0] = np.abs(Xsg[col][0]  - Xsg[col][1])
    Xsg[col][1] = np.abs(Xsg[col][1] - Xsg[col][2])
    Xsg[col][2] = np.abs(Xsg[col][2] - Xsg[col][0])

Xsg.rename(index={0:'0-1', 1:'1-2', 2: '2-0'}, inplace=True)
# Xsg.style
print(len(X))
print(len(y))
# Out:
# C:\Users\Luke\AppData\Local\Temp\ipykernel_2536\286685008.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col][nas] = np.nan
# <style type="text/css">
# </style>
# <table id="T_55765">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55765_level0_col0" class="col_heading level0 col0" >ppt_id</th>
#       <th id="T_55765_level0_col1" class="col_heading level0 col1" >p_correct</th>
#       <th id="T_55765_level0_col2" class="col_heading level0 col2" >mean_confidence</th>
#       <th id="T_55765_level0_col3" class="col_heading level0 col3" >hn_enc</th>
#       <th id="T_55765_level0_col4" class="col_heading level0 col4" >dwell_obj1_enc</th>
#       <th id="T_55765_level0_col5" class="col_heading level0 col5" >dwell_pp_enc</th>
#       <th id="T_55765_level0_col6" class="col_heading level0 col6" >dwell_table_enc</th>
#       <th id="T_55765_level0_col7" class="col_heading level0 col7" >dwell_other_enc</th>
#       <th id="T_55765_level0_col8" class="col_heading level0 col8" >t_first_array_enc</th>
#       <th id="T_55765_level0_col9" class="col_heading level0 col9" >t_first_obj1_enc</th>
#       <th id="T_55765_level0_col10" class="col_heading level0 col10" >dispersion_mean_enc</th>
#       <th id="T_55765_level0_col11" class="col_heading level0 col11" >velocity_mean_total_enc</th>
#       <th id="T_55765_level0_col12" class="col_heading level0 col12" >n_blinks_enc</th>
#       <th id="T_55765_level0_col13" class="col_heading level0 col13" >p_trackloss_enc</th>
#       <th id="T_55765_level0_col14" class="col_heading level0 col14" >hn_ret</th>
#       <th id="T_55765_level0_col15" class="col_heading level0 col15" >dwell_obj1_ret</th>
#       <th id="T_55765_level0_col16" class="col_heading level0 col16" >dwell_pp_ret</th>
#       <th id="T_55765_level0_col17" class="col_heading level0 col17" >dwell_table_ret</th>
#       <th id="T_55765_level0_col18" class="col_heading level0 col18" >dwell_other_ret</th>
#       <th id="T_55765_level0_col19" class="col_heading level0 col19" >t_first_array_ret</th>
#       <th id="T_55765_level0_col20" class="col_heading level0 col20" >t_first_obj1_ret</th>
#       <th id="T_55765_level0_col21" class="col_heading level0 col21" >dispersion_mean_ret</th>
#       <th id="T_55765_level0_col22" class="col_heading level0 col22" >velocity_mean_total_ret</th>
#       <th id="T_55765_level0_col23" class="col_heading level0 col23" >n_blinks_ret</th>
#       <th id="T_55765_level0_col24" class="col_heading level0 col24" >p_trackloss_ret</th>
#       <th id="T_55765_level0_col25" class="col_heading level0 col25" >hn_diff</th>
#       <th id="T_55765_level0_col26" class="col_heading level0 col26" >dwell_total_diff</th>
#       <th id="T_55765_level0_col27" class="col_heading level0 col27" >dwell_obj1_diff</th>
#       <th id="T_55765_level0_col28" class="col_heading level0 col28" >dwell_pp_diff</th>
#       <th id="T_55765_level0_col29" class="col_heading level0 col29" >dwell_table_diff</th>
#       <th id="T_55765_level0_col30" class="col_heading level0 col30" >dwell_other_diff</th>
#       <th id="T_55765_level0_col31" class="col_heading level0 col31" >t_first_array_diff</th>
#       <th id="T_55765_level0_col32" class="col_heading level0 col32" >t_first_obj1_diff</th>
#       <th id="T_55765_level0_col33" class="col_heading level0 col33" >dispersion_mean_diff</th>
#       <th id="T_55765_level0_col34" class="col_heading level0 col34" >velocity_mean_total_diff</th>
#       <th id="T_55765_level0_col35" class="col_heading level0 col35" >pupil_diam_centre_diff</th>
#       <th id="T_55765_level0_col36" class="col_heading level0 col36" >pupil_diam_spread_diff</th>
#       <th id="T_55765_level0_col37" class="col_heading level0 col37" >n_blinks_diff</th>
#       <th id="T_55765_level0_col38" class="col_heading level0 col38" >p_trackloss_diff</th>
#       <th id="T_55765_level0_col39" class="col_heading level0 col39" >d_kl</th>
#       <th id="T_55765_level0_col40" class="col_heading level0 col40" >ea_td</th>
#       <th id="T_55765_level0_col41" class="col_heading level0 col41" >group</th>
#       <th id="T_55765_level0_col42" class="col_heading level0 col42" >age</th>
#       <th id="T_55765_level0_col43" class="col_heading level0 col43" >sex</th>
#       <th id="T_55765_level0_col44" class="col_heading level0 col44" >yoe</th>
#       <th id="T_55765_level0_col45" class="col_heading level0 col45" >NART</th>
#       <th id="T_55765_level0_col46" class="col_heading level0 col46" >Ravens</th>
#       <th id="T_55765_level0_col47" class="col_heading level0 col47" >Camden</th>
#       <th id="T_55765_level0_col48" class="col_heading level0 col48" >FCSRT D FR</th>
#       <th id="T_55765_level0_col49" class="col_heading level0 col49" >FCSRT D TR</th>
#       <th id="T_55765_level0_col50" class="col_heading level0 col50" >TMT</th>
#       <th id="T_55765_level0_col51" class="col_heading level0 col51" >Rey Copy</th>
#       <th id="T_55765_level0_col52" class="col_heading level0 col52" >Rey Delayed</th>
#       <th id="T_55765_level0_col53" class="col_heading level0 col53" >DST</th>
#       <th id="T_55765_level0_col54" class="col_heading level0 col54" >ACE-III_attention</th>
#       <th id="T_55765_level0_col55" class="col_heading level0 col55" >ACE-III_verbalfluency</th>
#       <th id="T_55765_level0_col56" class="col_heading level0 col56" >ACE-III_memory</th>
#       <th id="T_55765_level0_col57" class="col_heading level0 col57" >ACE-III_language</th>
#       <th id="T_55765_level0_col58" class="col_heading level0 col58" >ACE-III_visuospatial</th>
#       <th id="T_55765_level0_col59" class="col_heading level0 col59" >ACE-III_perceptual</th>
#       <th id="T_55765_level0_col60" class="col_heading level0 col60" >dwell_MO-SOs_ret</th>
#       <th id="T_55765_level0_col61" class="col_heading level0 col61" >4MT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55765_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_55765_row0_col0" class="data row0 col0" >41</td>
#       <td id="T_55765_row0_col1" class="data row0 col1" >0.666667</td>
#       <td id="T_55765_row0_col2" class="data row0 col2" >7.296296</td>
#       <td id="T_55765_row0_col3" class="data row0 col3" >0.581240</td>
#       <td id="T_55765_row0_col4" class="data row0 col4" >0.131725</td>
#       <td id="T_55765_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_55765_row0_col6" class="data row0 col6" >0.161238</td>
#       <td id="T_55765_row0_col7" class="data row0 col7" >0.036934</td>
#       <td id="T_55765_row0_col8" class="data row0 col8" >606.185185</td>
#       <td id="T_55765_row0_col9" class="data row0 col9" >2385.222222</td>
#       <td id="T_55765_row0_col10" class="data row0 col10" >0.101736</td>
#       <td id="T_55765_row0_col11" class="data row0 col11" >0.006461</td>
#       <td id="T_55765_row0_col12" class="data row0 col12" >1.685185</td>
#       <td id="T_55765_row0_col13" class="data row0 col13" >0.084590</td>
#       <td id="T_55765_row0_col14" class="data row0 col14" >0.714908</td>
#       <td id="T_55765_row0_col15" class="data row0 col15" >0.156296</td>
#       <td id="T_55765_row0_col16" class="data row0 col16" >0.003987</td>
#       <td id="T_55765_row0_col17" class="data row0 col17" >0.161093</td>
#       <td id="T_55765_row0_col18" class="data row0 col18" >0.046003</td>
#       <td id="T_55765_row0_col19" class="data row0 col19" >235.574074</td>
#       <td id="T_55765_row0_col20" class="data row0 col20" >1837.833333</td>
#       <td id="T_55765_row0_col21" class="data row0 col21" >0.067437</td>
#       <td id="T_55765_row0_col22" class="data row0 col22" >0.007067</td>
#       <td id="T_55765_row0_col23" class="data row0 col23" >0.574074</td>
#       <td id="T_55765_row0_col24" class="data row0 col24" >0.025501</td>
#       <td id="T_55765_row0_col25" class="data row0 col25" >0.133667</td>
#       <td id="T_55765_row0_col26" class="data row0 col26" >0.019870</td>
#       <td id="T_55765_row0_col27" class="data row0 col27" >0.024571</td>
#       <td id="T_55765_row0_col28" class="data row0 col28" >0.003987</td>
#       <td id="T_55765_row0_col29" class="data row0 col29" >-0.000146</td>
#       <td id="T_55765_row0_col30" class="data row0 col30" >0.009069</td>
#       <td id="T_55765_row0
# <style type="text/css">
# </style>
# <table id="T_afb37">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_afb37_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_afb37_level0_col1" class="col_heading level0 col1" >female_p</th>
#       <th id="T_afb37_level0_col2" class="col_heading level0 col2" >age</th>
#       <th id="T_afb37_level0_col3" class="col_heading level0 col3" >yoe</th>
#       <th id="T_afb37_level0_col4" class="col_heading level0 col4" >Ravens</th>
#       <th id="T_afb37_level0_col5" class="col_heading level0 col5" >NART</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_afb37_level0_row0" class="row_heading level0 row0" >O</th>
#       <td id="T_afb37_row0_col0" class="data row0 col0" >20</td>
#       <td id="T_afb37_row0_col1" class="data row0 col1" >0.55</td>
#       <td id="T_afb37_row0_col2" class="data row0 col2" >73.02</td>
#       <td id="T_afb37_row0_col3" class="data row0 col3" >15.68</td>
#       <td id="T_afb37_row0_col4" class="data row0 col4" >8.00</td>
#       <td id="T_afb37_row0_col5" class="data row0 col5" >40.28</td>
#     </tr>
#     <tr>
#       <th id="T_afb37_level0_row1" class="row_heading level0 row1" >P</th>
#       <td id="T_afb37_row1_col0" class="data row1 col0" >8</td>
#       <td id="T_afb37_row1_col1" class="data row1 col1" >0.25</td>
#       <td id="T_afb37_row1_col2" class="data row1 col2" >67.65</td>
#       <td id="T_afb37_row1_col3" class="data row1 col3" >13.71</td>
#       <td id="T_afb37_row1_col4" class="data row1 col4" >5.71</td>
#       <td id="T_afb37_row1_col5" class="data row1 col5" >38.86</td>
#     </tr>
#     <tr>
#       <th id="T_afb37_level0_row2" class="row_heading level0 row2" >Y</th>
#       <td id="T_afb37_row2_col0" class="data row2 col0" >27</td>
#       <td id="T_afb37_row2_col1" class="data row2 col1" >0.81</td>
#       <td id="T_afb37_row2_col2" class="data row2 col2" >23.89</td>
#       <td id="T_afb37_row2_col3" class="data row2 col3" >16.19</td>
#       <td id="T_afb37_row2_col4" class="data row2 col4" >9.96</td>
#       <td id="T_afb37_row2_col5" class="data row2 col5" >30.59</td>
#     </tr>
#   </tbody>
# </table>
# 54
# 54
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # check collinearity

# %%
# heatmap correlation plot
corr = df.corr()
sort_corr = corr.abs().unstack().sort_values(ascending=False).drop_duplicates()
print(sort_corr[:30])
# Out:
# ppt_id                   ppt_id                     1.000000
# dwell_obj1_diff          dwell_obj1_ret             0.878693
# n_blinks_ret             p_trackloss_ret            0.867218
# hn_ret                   d_kl                       0.862313
# n_blinks_ret             n_blinks_enc               0.861197
# dispersion_mean_diff     dispersion_mean_enc        0.859198
# dwell_obj1_enc           dwell_table_enc            0.855692
# t_first_obj1_enc         ea_td                      0.850380
# p_trackloss_enc          n_blinks_enc               0.844054
# p_trackloss_ret          p_trackloss_enc            0.817273
# t_first_obj1_enc         dwell_table_enc            0.800804
# p_trackloss_enc          n_blinks_ret               0.782201
# t_first_obj1_enc         t_first_obj1_ret           0.779097
# p_trackloss_enc          t_first_obj1_enc           0.764026
# ea_td                    t_first_obj1_ret           0.762955
# t_first_obj1_ret         p_trackloss_ret            0.758516
# dwell_table_ret          t_first_obj1_ret           0.757221
# dwell_other_ret          dwell_other_enc            0.753733
# dwell_obj1_enc           t_first_obj1_enc           0.749961
# d_kl                     t_first_obj1_ret           0.748179
# dwell_table_ret          dwell_table_enc            0.729047
# p_trackloss_ret          n_blinks_enc               0.717780
# dwell_table_ret          t_first_obj1_enc           0.711827
# d_kl                     p_trackloss_enc            0.693700
# hn_ret                   t_first_obj1_ret           0.691085
# p_trackloss_ret          t_first_obj1_enc           0.684652
# t_first_array_enc        dwell_other_enc            0.683320
# velocity_mean_total_enc  velocity_mean_total_ret    0.680687
# p_trackloss_diff         n_blinks_diff              0.680448
# d_kl                     p_trackloss_ret            0.677017
# dtype: float64

# %% [markdown]
# # space to plot basic charts

# %%
# 
ax = plt.figure().add_subplot()
replace_map = {'P': 0, 'O': 1, 'Y': 2}
y_c = df['group'].replace(replace_map)
x_col = 'dwell_other_enc'
y_col = 'p_correct'
ax.scatter(df[x_col], df[y_col], c=y_c)
ax.set_xlabel(x_col)
ax.set_ylabel(y_col)

# zcol = 'p_correct'
# ax = plt.figure().add_subplot(111, projection='3d')
# ax.scatter(df[x_col], df[y_col], df[zcol], c=y)

ax = plt.figure().add_subplot()
ax.hist(df[x_col])

ax = plt.figure().add_subplot()
df.groupby(by='group').boxplot(column=x_col, subplots=False)
# Out:
# <AxesSubplot:>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# # print out remaining predictor columns

# print(len(df.columns))
# for col in df.columns:
#     print(col)

# %% [markdown]
# # feature selection

# %%
# then filter those where mean diff between groups is very low, then plot remaining
es_filter = 0.5  # effect size filter
filtered_cols = []
for col in Xsg.columns:
    if np.sum(Xsg[col] > es_filter) > 0:
        filtered_cols.append(col)
print((filtered_cols))
# Out:
# ['p_correct', 'mean_confidence', 'hn_enc', 't_first_array_enc', 'dispersion_mean_enc', 'n_blinks_enc', 'p_trackloss_enc', 'dwell_pp_ret', 'dwell_table_ret', 't_first_array_ret', 'velocity_mean_total_ret', 'hn_diff', 'dwell_total_diff', 'dwell_pp_diff', 'dwell_table_diff', 't_first_array_diff', 'dispersion_mean_diff', 'pupil_diam_centre_diff', 'p_trackloss_diff', 'Camden', 'FCSRT D FR', 'TMT', 'Rey Delayed', 'DST', '4MT']

# %%
# select by anova f-score threshold
# NOTE: can probably do this through sklearn using feature_selection.f_classif
p_thresh = 0.05
import scipy.stats as stats
# stats f_oneway functions takes the groups as input and returns ANOVA F and p value
anova_filt_cols = []
# ANOVA
print("anova")
for col in Xs_df.columns:
    P = Xs_df[col][y == 0]
    O = Xs_df[col][y == 1]
    Y = Xs_df[col][y == 2]
    fvalue, pvalue = stats.f_oneway(P, O, Y)
    if pvalue < p_thresh:
        print(f"col: {col}, f: {fvalue:.3f}, p: {pvalue:.3f})")
        anova_filt_cols.append(col)
        
print("t-test")
p_thresh = 0.05
for col in Xs_df.columns:
    P = Xs_df[col][y == 0]
    O = Xs_df[col][y == 1]
    # Y = Xs_df[col][y == 2]
    tvalue, pvalue = stats.ttest_ind(P, O, nan_policy='omit', random_state=0)
    if pvalue < p_thresh:
        print(f"col: {col}, t: {tvalue:.3f}, p: {pvalue:.3f})")
        anova_filt_cols.append(col)
# Out:
# anova
# col: p_correct, f: 8.752, p: 0.001)
# col: dwell_pp_ret, f: 6.966, p: 0.002)
# col: dwell_table_ret, f: 4.946, p: 0.011)
# col: dwell_pp_diff, f: 6.966, p: 0.002)
# col: pupil_diam_centre_diff, f: 7.887, p: 0.001)
# col: FCSRT D FR, f: 19.196, p: 0.000)
# col: TMT, f: 9.147, p: 0.000)
# col: Rey Delayed, f: 9.097, p: 0.000)
# col: DST, f: 16.280, p: 0.000)
# col: 4MT, f: 11.471, p: 0.000)
# t-test
# col: FCSRT D FR, t: -4.328, p: 0.000)
# col: Rey Delayed, t: -3.021, p: 0.006)
# C:\Users\Luke\anaconda3\envs\alloeyepy\lib\site-packages\scipy\stats\_stats_py.py:3903: ConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(stats.ConstantInputWarning(msg))

# %%
# use sklearn feature selection tools
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.datasets import load_digits
k = 10
kbest = SelectKBest(f_classif, k=k)
kbest_fit = kbest.fit(X, y)
kbest_features = kbest_fit.get_feature_names_out()
print(kbest_features)
# Out:
# ['p_correct' 'dwell_pp_ret' 'dwell_table_ret' 'dwell_pp_diff'
#  'pupil_diam_centre_diff' 'FCSRT D FR' 'TMT' 'Rey Delayed' 'DST' '4MT']
# C:\Users\Luke\anaconda3\envs\alloeyepy\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [4] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\Luke\anaconda3\envs\alloeyepy\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw

# %%
# Cross-validated logistic regression with L1 regularisation (Lasso)

from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import train_test_split, GridSearchCV, LeaveOneOut, LeavePOut, cross_val_score, ParameterGrid, StratifiedKFold
from sklearn.metrics import f1_score, make_scorer
from IPython.display import display
# X = X.to_numpy()

def logreg_l1_feat_output(logreg):
    # print(len(logreg.coef_))
    bool_feats = logreg.coef_[0] != 0
    table_dict = {
        "features": logreg.feature_names_in_[bool_feats]
    }
    for i in range(len(logreg.coef_)):
        table_dict.update({f"coefs{i}": logreg.coef_[i][bool_feats]})
    for i in range(len(logreg.coef_)):
        table_dict.update({f"odds{i}": np.exp(logreg.coef_[i][bool_feats])})
    # print(table_dict)
    out_tab = pd.DataFrame(table_dict)
    return out_tab
    
def gridsearchCV_logreg(X, y, params, cv):
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
    f1 = make_scorer(f1_score , average='weighted')
    grid_search = GridSearchCV(LogisticRegression(penalty='l1', solver='liblinear', max_iter=1000), 
                               params, cv=cv, return_train_score=True, scoring=f1)
    grid_search.fit(X_train, y_train)
    
    print("Training set f1 score: {:.2f}".format(grid_search.score(X_train, y_train)))
    print("Test set f1 score: {:.2f}".format(grid_search.score(X_test, y_test)))
    print("Best parameters: {}".format(grid_search.best_params_))
    print("Mean cross-validation score for best params: {:.2f}".format(grid_search.best_score_))
    display(pd.DataFrame(grid_search.cv_results_).style)
    grid_search.best_index_
    logreg = LogisticRegression(**grid_search.best_params_, penalty='l1', solver='liblinear', max_iter=1000)
    clf = logreg.fit(X_train, y_train)
    # pred_logreg = logreg.predict(X_test)
    print(f"refit best params score: {clf.score(X_test, y_test):.3f}")
    
    # build feature coef table
    return logreg_l1_feat_output(logreg)
    
def nested_cv(X, y, inner_cv, outer_cv, Classifier, parameter_grid, stable_params, f1=True):
    outer_scores = []
    # for each split of the data in the outer cross-validation
    # (split method returns indices of training and test parts)
    X = X.reset_index(drop=True)
    i = 0
    feat_dict = {}
    feat_df_len = 0
    coef_dict = {}
    for training_samples, test_samples in outer_cv.split(X, y):
        # find best parameter using inner cross-validation
        best_parms = {}
        best_score = -np.inf
        # iterate over parameters
        for parameters in parameter_grid:
            # accumulate score over inner splits
            cv_scores = []
            # iterate over inner cross-validation
            # print(training_samples)
            for inner_train, inner_test in inner_cv.split(X.loc[training_samples], y[training_samples]):
                # build classifier given parameters and training data
                # print(parameters)
                # print(stable_params)
                clf = Classifier(**parameters, **stable_params)
                # print(clf)
                clf.fit(X.loc[inner_train], y[inner_train])
                # evaluate on inner test set
                score = clf.score(X.loc[inner_test], y[inner_test])
                f1_sc = f1_score(y[inner_test], clf.predict(X.loc[inner_test]), average='weighted')
                inn_score = f1_sc if f1 else score
                cv_scores.append(inn_score)
            
            # compute mean score over inner folds
            mean_score = np.mean(cv_scores)
            if mean_score > best_score:
                # if better than so far, remember parameters
                best_score = mean_score
                best_params = parameters

        # build classifier on best parameters using outer training set
        print("Best parameters: {}".format(best_params))
        clf = Classifier(**best_params, **stable_params)
        clf.fit(X.loc[training_samples], y[training_samples])
        # print(clf.coef_)
        if 'l1' in stable_params.values():
            k = f"features{i}"
            feat_dict.update({k: clf.feature_names_in_[clf.coef_[0] != 0]})
            feat_df_len = np.max([feat_df_len, len(feat_dict[k])])
        i += 1
        # evaluate
        f1_sc = f1_score(y[test_samples], clf.predict(X.loc[test_samples]), average='weighted')
        score = clf.score(X.loc[test_samples], y[test_samples])
        out_score = f1_sc if f1 else score
        outer_scores.append(out_score)
    if 'l1' in stable_params.values():
        for key in feat_dict.keys():
            len_diff = feat_df_len - len(feat_dict[key])
            if len_diff > 0:
                for i in range(len_diff):
                    feat_dict[key] = np.append(feat_dict[key], "")
            # print(f"{len(feat_dict[key])}, {feat_df_len}")
           
    return np.array(outer_scores), pd.DataFrame(feat_dict)

def nested_cv_feats(X, y, inner_cv, outer_cv, Classifier, parameter_grid, stable_params, f1=True, common_thresh=1):
    scores, feat_df = nested_cv(X, y, inner_cv, outer_cv, Classifier, parameter_grid, stable_params, f1)
    print(f"Outer CV scores: {scores}")
    print(f"Mean CV score: {np.mean(scores):.3f}")
    all_l1_feats = np.unique(feat_df.iloc[:, 1:])
    all_l1_feats = all_l1_feats[all_l1_feats != '']
    common_l1_feats = []
    all_feats = feat_df.values.tolist()
    all_feats = np.array([item for sublist in all_feats for item in sublist])
    for col in feat_df.columns:
        for feat in feat_df[col]:
            if len(all_feats[all_feats == feat]) >= common_thresh and feat not in common_l1_feats and feat != '':
                common_l1_feats.append(feat)
    common_l1_feats = np.array(common_l1_feats)
    return all_l1_feats, common_l1_feats
    
# logreg_params = {'C':[2]}
# cv = LeaveOneOut()
# # cv = 25
# gridsearchCV_logreg(X, y, logreg_params, cv)

cv = 8

stable_params = {'penalty': 'l1', 'solver': 'liblinear', 'max_iter': 10000}
# logreg_params = {'C':[1, 2, 3]}
logreg_params = {'C': [2]}
# inn_cv = LeavePOut(p=2)
inn_cv = LeaveOneOut()
# inn_cv = StratifiedKFold(4)
common_thresh = 3
print("all group logreg l1")
all_group_all_l1, all_group_common_l1 = nested_cv_feats(Xs_df, y, inn_cv, StratifiedKFold(cv), LogisticRegression, ParameterGrid(logreg_params), stable_params, common_thresh=common_thresh)
all_group_common_l1

# predicting P from others
y1 = np.where(y > 0, 1, 0)
logreg_params = {'C':[2, 4, 6]}
print("mci from others logreg l1")
mci_all_l1, mci_common_l1 = nested_cv_feats(Xs_df, y1, inn_cv, StratifiedKFold(cv), LogisticRegression, ParameterGrid(logreg_params), stable_params, common_thresh=common_thresh)
# svc
from sklearn.svm import LinearSVC
stable_params = {'penalty': 'l1', 'max_iter': 100000, 'loss': 'squared_hinge', 'dual': False}
# logreg_params = {'C':[1, 2, 3]}
lsvc_params = {'C': [0.01, 0.1, 1, 10]}
# inn_cv = LeavePOut(p=2)
inn_cv = LeaveOneOut()
# inn_cv = StratifiedKFold(4)
common_thresh = 3
print("all group svc l1")
all_group_all_l1_svc, all_group_common_l1_svc = nested_cv_feats(Xs_df, y, inn_cv, StratifiedKFold(cv), LinearSVC, ParameterGrid(lsvc_params), stable_params, common_thresh=common_thresh)
print("mci from others svc l1")
mci_all_l1_svc, mci_common_l1_svc = nested_cv_feats(Xs_df, y1, inn_cv, StratifiedKFold(cv), LinearSVC, ParameterGrid(lsvc_params), stable_params, common_thresh=common_thresh)
# Out:
# all group logreg l1
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Outer CV scores: [0.35714286 0.67687075 0.71428571 0.65079365 0.68027211 0.71428571
#  0.83333333 0.42857143]
# Mean CV score: 0.632
# mci from others logreg l1
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Outer CV scores: [1.         1.         0.79120879 0.87445887 0.71428571 0.87445887
#  1.         1.        ]
# Mean CV score: 0.907
# all group svc l1
# Best parameters: {'C': 0.1}
# Best parameters: {'C': 0.1}
# Best parameters: {'C': 0.1}
# Best parameters: {'C': 0.1}
# Best parameters: {'C': 0.1}
# Best parameters: {'C': 0.1}
# Best parameters: {'C': 0.1}
# Best parameters: {'C': 0.1}
# Outer CV scores: [0.85306122 0.72380952 0.53061224 0.68027211 0.54421769 0.54285714
#  0.76666667 0.28571429]
# Mean CV score: 0.616
# mci from others svc l1
# Best parameters: {'C': 1}
# Best parameters: {'C': 1}
# Best parameters: {'C': 1}
# Best parameters: {'C': 1}
# Best parameters: {'C': 1}
# Best parameters: {'C': 1}
# Best parameters: {'C': 10}
# Best parameters: {'C': 10}
# Outer CV scores: [1.         1.         1.         0.87445887 0.62337662 0.62337662
#  1.         1.        ]
# Mean CV score: 0.890

# %%
print(mci_common_l1)
print(mci_common_l1_svc)
# Out:
# ['dwell_obj1_enc' 't_first_array_enc' 'dispersion_mean_enc' 'n_blinks_enc'
#  'dispersion_mean_ret' 'pupil_diam_centre_diff' 'pupil_diam_spread_diff'
#  'FCSRT D FR' 'TMT' 'Rey Delayed' '4MT' 'mean_confidence' 'hn_enc'
#  'Camden' 'dwell_total_diff']
# ['mean_confidence' 'dwell_obj1_enc' 't_first_array_enc'
#  'dispersion_mean_enc' 'n_blinks_enc' 'dwell_obj1_ret' 'dwell_pp_ret'
#  'dispersion_mean_ret' 'dwell_total_diff' 'dwell_pp_diff'
#  'velocity_mean_total_diff' 'pupil_diam_spread_diff' 'd_kl' 'FCSRT D FR'
#  'TMT' 'Rey Delayed' 'DST' '4MT' 'hn_enc' 'Camden' 'Rey Copy'
#  'pupil_diam_centre_diff']

# %%
# plot selected features

def subboxplots(df, cols, xlabs=['O', 'P', 'Y']):
    n_cols = 4
    n_rows = int(np.ceil(len(cols)/n_cols))

    fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 10), dpi=100)
    plt.subplots_adjust(left=0.1,
                        bottom=0.1,
                        right=0.6,
                        top=0.9,
                        wspace=0.6,
                        hspace=0.6)
    # ticks = list(replace_map.values())
    # labels = list(replace_map.keys())
    for i in range(len(cols)):
        row = int(np.floor(i/n_cols))
        col = i % n_cols
        feat = cols[i]
        plt.sca(axes[row, col])
        df.groupby(by='group').boxplot(column=feat, subplots=False)
        # axes[row, col].set_xticks(ticks)
        axes[row, col].set_xticklabels(xlabs)
        axes[row, col].set_title(feat)

# subboxplots(df, filtered_cols)
# subboxplots(df, mci_all_l1)

# %%
feats = ['p_correct', 'hn_enc', 'd_kl', 'ea_td', 'dwell_MO-SOs_ret', 't_first_obj1_enc', 'dwell_table_ret', 't_first_obj1_ret', 'pupil_diam_centre_diff', 
        'dwell_pp_ret',  'dispersion_mean_enc', 'n_blinks_enc']
subboxplots(df, feats)
NP = ['FCSRT D FR', 'TMT', 'Rey Delayed', 'DST', '4MT']
subboxplots(df, NP)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df_filt = df.loc[:, filtered_cols]
df_filt['group'] = y
# sns.pairplot(df_filt, hue='group')

# %%
# # pca
# from sklearn.decomposition import PCA

# # keep the first two principal components of the data
# n_comp = 20
# pca = PCA(n_components=n_comp)
# # fit PCA model to breast cancer data
# pca.fit(Xs)
# # transform data onto the first two principal components
# X_pca = pca.transform(Xs)
# print("Original shape: {}".format(str(Xs.shape)))
# print("Reduced shape: {}".format(str(X_pca.shape)))

# # plot first vs. second principal component, colored by class
# # mycols=np.array(["blue","red"])
# plt.figure(figsize=(8, 8))
# plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y)
# # plt.legend(['malignant', 'benign'], loc="best")
# plt.gca().set_aspect("equal")
# plt.xlabel("First principal component")
# plt.ylabel("Second principal component");

# plt.matshow(pca.components_, cmap='binary')
# plt.yticks([0, 1], ["First component", "Second component"])
# plt.colorbar()
# plt.xticks(range(len(X_cols)),
# X_cols, rotation=60, ha='left')
# plt.xlabel("Feature")
# plt.ylabel("Principal components");

# fig, ax = plt.subplots()
# ax.bar(range(0,n_comp), pca.explained_variance_ratio_)
# ax.set_xlabel('PCs')
# ax.set_ylabel('explained variance');

# %%
# Out:
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Outer CV scores: [0.69220779 0.6952381  0.805      0.52207792 0.72727273]
# Mean CV score: 0.688
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Best parameters: {'C': 2}
# Outer CV scores: [1.         0.85263158 0.8        1.         1.        ]
# Mean CV score: 0.931
# Best parameters: {'C': 0.1}
# Best parameters: {'C': 0.1}
# Best parameters: {'C': 0.1}
# Best parameters: {'C': 0.1}
# Best parameters: {'C': 0.1}
# Outer CV scores: [0.7        0.6        0.57142857 0.58636364 0.74382716]
# Mean CV score: 0.640
# Best parameters: {'C': 10}
# Best parameters: {'C': 10}
# Best parameters: {'C': 10}
# Best parameters: {'C': 10}
# Best parameters: {'C': 1}
# Outer CV scores: [1.         0.85263158 0.91372549 0.91372549 1.        ]
# Mean CV score: 0.936

# %%
# recursive feature elimination with cross validation
from sklearn.feature_selection import RFECV
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, AdaBoostClassifier
from sklearn.svm import SVC
estimator = AdaBoostClassifier
# find a good estimator
# param_grid = {'n_estimators': [50, 100, 200, 500], 'learning_rate': [0.05, 0.1, 0.5], 'max_depth': [1, 2]}
# param_grid = {'n_estimators': [100, 200, 500],  'max_depth': [1, 2]}
param_grid = {'n_estimators': [100, 200, 500], 'learning_rate': [0.05, 0.1, 0.5]}
# param_grid = {'C': [0.00005, 0.0001, 0.0005, 0.0007]}
stable_params = {'random_state': 0}
scores, _ = nested_cv(X, y, inn_cv, StratifiedKFold(5), estimator, ParameterGrid(param_grid), stable_params)
# Out:
# Best parameters: {'learning_rate': 0.5, 'n_estimators': 500}
# Best parameters: {'learning_rate': 0.5, 'n_estimators': 500}
# Best parameters: {'learning_rate': 0.5, 'n_estimators': 500}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [32], in <cell line: 12>()
#      10 # param_grid = {'C': [0.00005, 0.0001, 0.0005, 0.0007]}
#      11 stable_params = {'random_state': 0}
# ---> 12 scores, _ = nested_cv(X, y, inn_cv, StratifiedKFold(5), estimator, ParameterGrid(param_grid), stable_params)
#
# Input In [16], in nested_cv(X, y, inner_cv, outer_cv, Classifier, parameter_grid, stable_params, f1)
#      67 clf = Classifier(**parameters, **stable_params)
#      68 # print(clf)
# ---> 69 clf.fit(X.loc[inner_train], y[inner_train])
#      70 # evaluate on inner test set
#      71 score = clf.score(X.loc[inner_test], y[inner_test])
#
# File ~\anaconda3\envs\alloeyepy\lib\site-packages\sklearn\ensemble\_weight_boosting.py:486, in AdaBoostClassifier.fit(self, X, y, sample_weight)
#     483     raise ValueError("algorithm %s is not supported" % self.algorithm)
#     485 # Fit
# --> 486 return super().fit(X, y, sample_weight)
#
# File ~\anaconda3\envs\alloeyepy\lib\site-packages\sklearn\ensemble\_weight_boosting.py:145, in BaseWeightBoosting.fit(self, X, y, sample_weight)
#     141 random_state = check_random_state(self.random_state)
#     143 for iboost in range(self.n_estimators):
#     144     # Boosting step
# --> 145     sample_weight, estimator_weight, estimator_error = self._boost(
#     146         iboost, X, y, sample_weight, random_state
#     147     )
#     149     # Early termination
#     150     if sample_weight is None:
#
# File ~\anaconda3\envs\alloeyepy\lib\site-packages\sklearn\ensemble\_weight_boosting.py:548, in AdaBoostClassifier._boost(self, iboost, X, y, sample_weight, random_state)
#     509 """Implement a single boost.
#     510
#     511 Perform a single boost according to the real multi-class SAMME.R
#    (...)
#     545     If None then boosting has terminated early.
#     546 """
#     547 if self.algorithm == "SAMME.R":
# --> 548     return self._boost_real(iboost, X, y, sample_weight, random_state)
#     550 else:  # elif self.algorithm == "SAMME":
#     551     return self._boost_discrete(iboost, X, y, sample_weight, random_state)
#
# File ~\anaconda3\envs\alloeyepy\lib\site-packages\sklearn\ensemble\_weight_boosting.py:557, in AdaBoostClassifier._boost_real(self, iboost, X, y, sample_weight, random_state)
#     554 """Implement a single boost using the SAMME.R real algorithm."""
#     555 estimator = self._make_estimator(random_state=random_state)
# --> 557 estimator.fit(X, y, sample_weight=sample_weight)
#     559 y_predict_proba = estimator.predict_proba(X)
#     561 if iboost == 0:
#
# File ~\anaconda3\envs\alloeyepy\lib\site-packages\sklearn\tree\_classes.py:937, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     899 def fit(
#     900     self, X, y, sample_weight=None, check_input=True, X_idx_sorted="deprecated"
#     901 ):
#     902     """Build a decision tree classifier from the training set (X, y).
#     903
#     904     Parameters
#    (...)
#     934         Fitted estimator.
#     935     """
# --> 937     super().fit(
#     938         X,
#     939         y,
#     940         sample_weight=sample_weight,
#     941         check_input=check_input,
#     942         X_idx_sorted=X_idx_sorted,
#     943     )
#     944     return self
#
# File ~\anaconda3\envs\alloeyepy\lib\site-packages\sklearn\tree\_classes.py:203, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     200 self.n_outputs_ = y.shape[1]
#     202 if is_classification:
# --> 203     check_classification_targets(y)
#     204     y = np.copy(y)
#     206     self.classes_ = []
#
# File ~\anaconda3\envs\alloeyepy\lib\site-packages\sklearn\utils\multiclass.py:189, in check_classification_targets(y)
#     178 def check_classification_targets(y):
#     179     """Ensure that target y is of a non-regression type.
#     180
#     181     Only the following target types (as defined in type_of_target) are allowed:
#    (...)
#     187     y : array-like
#     188     """
# --> 189     y_type = type_of_target(y)
#     190     if y_type not in [
#     191         "binary",
#     192         "multiclass",
#    (...)
#     195         "multilabel-sequences",
#     196     ]:
#     197         raise ValueError("Unknown label type: %r" % y_type)
#
# File ~\anaconda3\envs\alloeyepy\lib\site-packages\sklearn\utils\multiclass.py:327, in type_of_target(y)
#     324     _assert_all_finite(y)
#     325     return "continuous" + suffix
# --> 327 if (len(np.unique(y)) > 2) or (y.ndim >= 2 and len(y[0]) > 1):
#     328     return "multiclass" + suffix  # [1, 2, 3] or [[1., 2., 3]] or [[1, 2]]
#     329 else:
#
# File <__array_function__ internals>:180, in unique(*args, **kwargs)
#
# File ~\anaconda3\envs\alloeyepy\lib\site-packages\numpy\lib\arraysetops.py:272, in unique(ar, return_index, return_inverse, return_counts, axis)
#     270 ar = np.asanyarray(ar)
#     271 if axis is None:
# --> 272     ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     273     return _unpack_tuple(ret)
#     275 # axis was specified and not None
#
# File ~\anaconda3\envs\alloeyepy\lib\site-packages\numpy\lib\arraysetops.py:333, in _unique1d(ar, return_index, return_inverse, return_counts)
#     331     aux = ar[perm]
#     332 else:
# --> 333     ar.sort()
#     334     aux = ar
#     335 mask = np.empty(aux.shape, dtype=np.bool_)
#
# KeyboardInterrupt:

# %%
def RFECV_feats(Classifier, params, stable_params):
    estimator = Classifier(**params, **stable_params)
    selector = RFECV(estimator, step=1, cv=5)
    selector = selector.fit(X, y)
    return selector.feature_names_in_[selector.support_]

# %%
# tree-based feature selection
# RandomForest, GradientBoost, AdaBoost
top_params = {'n_estimators': 200, 'learning_rate': 0.05}
estimator = GradientBoostingClassifier(**top_params, **stable_params)
selector = RFECV(estimator, step=1, cv=5)
selector = selector.fit(X, y)
GB_RFE = selector.feature_names_in_[selector.support_]

# %%
clf = estimator.fit(X, y)
GB_FI = clf.feature_names_in_[clf.feature_importances_ > 0.05] 
GB_FI
print(list(GB_RFE))
# Out:
# ['hd_enc', 't_first_array_enc', 't_first_obj1_enc', 't_first_obj1_ret', 'dwell_total_diff', 'dwell_other_diff', 't_first_array_diff', 'pupil_diam_centre_diff', 'pupil_diam_spread_diff', 'FCSRT D FR', 'DST']

# %%
print(scores)
top_params =  {'n_estimators': 100,  'max_depth': 1}
RF_RFE = RFECV_feats(RandomForestClassifier, top_params, stable_params)
RF_RFE
# Out:
# [0.33333333 0.33333333 0.45       0.45       0.3968254 ]
# array(['t_first_obj1_enc', 't_first_obj1_ret', 'dwell_table_diff',
#        'pupil_diam_centre_diff', 'FCSRT D FR', 'TMT', 'DST', '4MT'],
#       dtype=object)

# %%
top_params = {'n_estimators': 200, 'learning_rate': 0.05}
Ada_RFE = RFECV_feats(AdaBoostClassifier, top_params, stable_params)
Ada_RFE
# Out:
# array(['dwell_other_enc', 't_first_obj1_enc', 't_first_array_diff',
#        'FCSRT D FR', 'DST'], dtype=object)

# %%
mci_common_l1_svc

# %%
X['group'] = y
subboxplots(X, mci_common_l1, xlabs=['P', 'O', 'Y'])

# %%
sub_X = X.loc[:, mci_common_l1]
print(cross_val_score(LogisticRegression(solver= 'liblinear', max_iter= 10000), sub_X, y1, cv=5))

# %%
# elastic net
