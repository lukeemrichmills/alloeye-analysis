# %% [markdown]
# ## spatial-temporal dynamics

# %%
# imports

import numpy as np
import pandas as pd
# %matplotlib widget
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import matplotlib.cm as cm
from matplotlib.animation import FuncAnimation
import itertools
import random
import seaborn as sns
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from src.d03_processing.BlinkProcessor import BlinkProcessor
from src.d03_processing.fixations.SignalProcessor import SignalProcessor
from src.d03_processing.fixations.I_VDT import I_VDT
from src.d00_utils.TaskObjects import *
from src.d03_processing.fixations.FixationProcessor import FixationProcessor
from src.d03_processing.TimepointProcessor import TimepointProcessor
from src.d01_data.fetch.fetch_timepoints import fetch_timepoints
from src.d01_data.fetch.fetch_viewings import fetch_viewings
from src.d01_data.fetch.fetch_trials import fetch_trials
from src.d01_data.fetch.fetch_timepoints import fetch_timepoints
from src.d03_processing.aoi import collision_sphere_radius
from src.d03_processing.feature_extract.to_viewing import to_viewing
from src.d03_processing.fixations.FixAlgos import *
from src.d03_processing.feature_calculate.viewing_compare_calcs import ea_td

from sklearn.cluster import KMeans
from scipy.linalg import orthogonal_procrustes
from scipy.spatial import procrustes

# %%
def get_center(obj, tps, y_adjust=0):
    # display(tps.iloc[:2, :].style)
    row = tps[tps.gaze_object == obj].reset_index(drop=True).iloc[0, :]
    center = (row.object_position_x, row.object_position_z, row.object_position_y + y_adjust)
    # print(f"{obj}: {row.gaze_object} {center}")
    return center

def plot_3d_probability_distribution(probability_map, voxel_centers, threshold=0.00002, ax=None, heatmap_translate=[0, 0, 0], alpha_scale=1.0):
    if ax is None:
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')

    # Extract x, y, z coordinates and probabilities
    x, y, z = voxel_centers[:, 0], voxel_centers[:, 1], voxel_centers[:, 2]
    x += heatmap_translate[0]
    y += heatmap_translate[1]
    z += heatmap_translate[2]
    prob = probability_map.flatten()
    idx = np.where(prob > threshold)[0]
    x, y, z = x[idx], y[idx], z[idx]
    prob = prob[idx]
    
    # Normalize probability values to the range [0,1] for use as alpha values
    p_norm = (prob - prob.min()) / (prob.max() - prob.min())

    # Scale alpha values by the alpha_scale parameter
    alpha = p_norm * alpha_scale
    
    # Create the colormap with the specified alpha scaling
    
    # Set color map and scale for probability
    # cmap options: jet, rainbow, OrRd, YlOrRd
    cmap = plt.cm.get_cmap('OrRd')
    colors = cmap(p_norm)
    colors[:, -1] *= alpha_scale * p_norm
    norm = plt.Normalize(vmin=np.min(prob), vmax=np.max(prob))
    print('min: ', np.min(prob), 'max: ', np.max(prob))

    # Create scatter plot
    # ax.scatter(x, z, y, c=prob, cmap=cmap, norm=norm, alpha=0.2)
    ax.scatter(x, z, y, c=colors)
    
    # set axes
    ax.set_xlim([-0.5, 0.5])
    ax.set_zlim([-0.5, 0.5])
    ax.set_ylim([-0.5, 0.5])

    # Set labels and title
    ax.set_xlabel('X')
    ax.set_ylabel('Z')
    ax.set_zlabel('Y')
    ax.set_title('3D Probability Distribution')

    # Add color bar
    mappable = plt.cm.ScalarMappable(norm=norm, cmap=cmap)
    mappable.set_array(prob)
    plt.colorbar(mappable)

    # Show plot
    plt.show()
    
def viewing_plot(tps, array_objects=None, gp_lab='table', gp_line=False, ax=None, alpha=0.5, prob_map=None, pmap_voxel_centers=None):
    if array_objects is None:
        full_objects = np.unique(tps.gaze_object)
        # array_objects = TaskObjects.array_and_invisible
        table_objects = ['InvisibleObject', *TaskObjects.array_objects]
        array_objects = full_objects[np.isin(full_objects,np.array(table_objects))]
        print(array_objects)

    if ax is None:
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')

    camera_pos = np.array([np.nanmean(tps.camera_x), np.nanmean(tps.camera_z), np.nanmean(tps.camera_y)])

    # plot gaze points as points, unless heatmap
    if prob_map is None:
        x, y, z = tps.gaze_collision_x.to_numpy(),tps.gaze_collision_y.to_numpy(),tps.gaze_collision_z.to_numpy()
        lab = tps.gaze_object == 'Table' if gp_lab=='table' else np.array(tps[gp_lab].to_numpy(), dtype=bool)
        no_lab = np.invert(lab)
        # print(lab)
        # print(no_lab)
        ax.scatter(x[lab], z[lab], y[lab], c='red', s=2, alpha=1)
        ax.scatter(x[no_lab], z[no_lab], y[no_lab], c='g', s=2, alpha=alpha)
        if gp_line:
            ax.plot(x, z, y, c='k', linewidth=0.4, alpha=alpha)

    # draw a cylinder to represent a table
    table_y_scale =  0.06538646
    table_center =  get_center('Table', tps) # center of the cylinder
    camera_vec = table_center - camera_pos
    # print(f"table: {table_center}")
    radius = 0.55  # radius of the cylinder
    height = table_y_scale * 2  # height of the cylinder
    resolution = 20

    # Create the cylinder mesh
    z = np.linspace(table_center[2]-height/2, table_center[2]+height/2, resolution)
    theta = np.linspace(0, 2*np.pi, resolution)
    theta_grid, z_grid = np.meshgrid(theta, z)
    x_grid = radius*np.cos(theta_grid) + table_center[0]
    y_grid = radius*np.sin(theta_grid) + table_center[1]

    # Create the Poly3DCollection
    verts = []
    for i in range(len(z)-1):
        verts += [list(zip(x_grid[i], y_grid[i], z_grid[i])),
                  list(zip(x_grid[i+1], y_grid[i+1], z_grid[i+1])),
                  list(zip(x_grid[i+1], y_grid[i+1], z_grid[i])),
                  list(zip(x_grid[i], y_grid[i], z_grid[i+1]))]
    table = Poly3DCollection(verts, facecolors=[1, 1, 1, 0], edgecolors=[0, 0, 0, 0.2], alpha=0.0)
    table.set_zsort('min')
    ax.add_collection3d(table)

    for obj in array_objects:
        sphere_center = get_center(obj, tps)
        sphere_radius = 0.12 if obj == 'InvisibleObject' else collision_sphere_radius(sphere_center, camera_pos)
        sphere_center = get_center(obj, tps, sphere_radius)
        # print(f"{obj}: {sphere_center}")
        # sphere_center = get_center(obj, tps)
        u = np.linspace(0, 2 * np.pi, 30)
        v = np.linspace(0, np.pi, 30)
        x = sphere_radius * np.outer(np.cos(u), np.sin(v)) + sphere_center[0]
        y = sphere_radius * np.outer(np.sin(u), np.sin(v)) + sphere_center[1]
        z = sphere_radius * np.outer(np.ones(np.size(u)), np.cos(v)) + sphere_center[2]
        c = [0, 0.8, 0.8, 0.5] if obj == 'InvisibleObject' else [0, 0, 1, 0.5]
        sphere = ax.plot_surface(x, y, z, color=c, alpha=0.05)
        sphere.set_edgecolor(c)
    
    if prob_map is not None:
        plot_3d_probability_distribution(prob_map, pmap_voxel_centers, 
                                         heatmap_translate=[table_center[0], 0.7, table_center[1]], 
                                         ax=ax)

    # set axis limits and labels
    ax_len = 0.55
    ax.set_xlim([table_center[0]-ax_len, table_center[0]+ax_len])
    ax.set_ylim([table_center[1]-ax_len, table_center[1]+ax_len])
    ax.set_zlim([table_center[2]-ax_len, table_center[2]+ax_len])
    ax.grid(False)

    # Hide axes ticks
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_zticks([])
    ax.set_axis_off()

    azimuthal_angle = 180 + (np.arctan2(camera_vec[1], camera_vec[0]) * 180 / np.pi)
    polar_angle = 180 - (np.arccos(camera_vec[2] / np.linalg.norm(camera_vec)) * 180 / np.pi)

    # Convert angles to radians
    azimuthal_angle_rad = np.deg2rad(azimuthal_angle)
    polar_angle_rad = np.deg2rad(polar_angle)
    # print(f'elev: {polar_angle}, azim: {azimuthal_angle}')
    ax.view_init(elev=polar_angle, azim=azimuthal_angle)



# def object_viewing_plot(tps, trial):

# %%
# data - 1 ppt first
old_pids = ['37', '38', '39', '40', '42', '44']
young_pids = ['12', '13', '14', '15', '16', '17', '5', '6', '10', '18', '21', '22', '23', '24', '25', '26']
mci_pids = ['50', '51', '52', '53', '57', '58']
cutoff = 7000   # ms
pid_groups = [young_pids, old_pids, mci_pids]
group_names = ['Younger', 'Older', 'MCI']
axes = []
configurations = [1]
upsample = 1  # ms
downsample = 15  #ms

# %%
pids = young_pids
n_pids = len(pids)
all_trials = fetch_trials(pids)
sig_cols = ('gaze_collision_x', 'gaze_collision_y', 'gaze_collision_z')

Ts_normed = []
Ms = None
for j, config in enumerate(configurations):
    t = np.arange(0, cutoff, downsample)
    tensors = None
    tens = None
    config_obj1_pos = []
    config_table_pos = []
    cluster_pids = []
    object_distance_mean_x, object_distance_mean_z = [], []
    
    # this is used to find an averaged view for 2d projection
    mean_camera_pos = []
    
    for i in range(n_pids):
        pid = pids[i]
        
        # fetch data
        tps = fetch_timepoints(pid, ret_epochs=['na'], configurations = [config], suppress_print=True)
        try:
            trial = all_trials[all_trials.trial_id == tps.trial_id[0]].reset_index(drop=True)
        except IndexError:
            pids.remove(pid)
            n_pids -= 1
            continue
                
        config_obj1_pos.append(np.array([trial.obj1_preshift_x[0], 0, trial.obj1_preshift_z[0]]))  # save for 2d projection later
        
        # participant's viewpoint
        camera_pos = np.array([np.nanmean(tps.camera_x),
                               np.nanmean(tps.camera_y),
                               np.nanmean(tps.camera_z)])  
        mean_camera_pos.append(camera_pos)

        
        
        # table position for zero adjustment
        table_x, table_z  = trial.table_location_x[0], trial.table_location_z[0]
        config_table_pos.append((table_x, table_z))
        
        # object distances for categorising configuration views
        object_distance_xs, object_distance_zs = [], []
        for o in range(1, 5):
            col = f"obj{o}_preshift"
            x_dist = trial[f"{col}_x"][0] - camera_pos[0]
            # print(x_dist)
            object_distance_xs.append(x_dist)
            object_distance_zs.append(trial[f"{col}_z"][0] - camera_pos[2])
        # print(np.mean(object_distance_xs))
        object_distance_mean_x.append(np.mean(object_distance_xs))
        object_distance_mean_z.append(np.mean(object_distance_zs))
        # print("iter")
        # print(object_distance_mean_x)
        # print(f"obj1 x: {trial.obj1_preshift_x[0] - table_x}, z: {trial.obj1_preshift_z[0] - table_z}")

        # None check
        if tps is None or len(tps) < 2:
            print(f"no timepoints")
            continue
            
        # signal preprocessing steps
        s_tps = SignalProcessor.sandwiched_gp_filter(tps.copy(deep=True))
        b_tps = BlinkProcessor(s_tps.copy(deep=True), max_blink_duration=1000, d_impute_threshold=0.16, impute_buffer_duration=8).timepoints
        if b_tps is None:
            print(f" invalid")
            continue
        f_tps = SignalProcessor.filter_timepoints(b_tps.copy(deep=True), downsample_to=downsample)
        
        # # plots and debugging
        # print(trial.trial_id[0])
        # print(f"anticlockwise: {trial.anticlockwise_move[0]}")
        # viewing_plot(f_tps)
        # plt.show()
        
        # upsample to 1ms and make all viewings the same length defined by cutoff
        xyz = None
        for col in sig_cols:
            up = SignalProcessor(f_tps[col].to_numpy(), f_tps.eye_timestamp_ms.to_numpy()).upsample_1d(1)      # signal processor class instance with signal and time
            up = up[:cutoff]
            if len(up) < cutoff:
                nans = np.empty(cutoff-len(up))
                up = np.append(up, nans.fill(np.nan))
            down = up[::downsample].reshape(-1, 1)
            
            # # adjust for table position differences
            # if col == 'gaze_collision_x':
            #     down -= table_x
            # elif col == 'gaze_collision_z':
            #     down -= table_z

            # concatenate 3d gaze points
            xyz = down if xyz is None else np.concatenate((xyz, down), axis=1)
            
        # ax = plt.figure().add_subplot(projection='3d')
        # ax.plot(xyz.T[0, :], xyz.T[2, :], xyz.T[1, :], 'r.', alpha=0.5, markersize=1)
        # ax.set_ylim([-0.7, 0.3])
        # ax.set_xlim([0, 1])
        # ax.set_zlim([0.3, 1.3])
        # ax.set_title("before concatenating")
        # plt.show()  
            
        # concatenate 4d gaze-time points
        xyz = np.reshape(xyz, (len(xyz), 3, 1))
        

        # print(xyz.shape)
        tens = xyz if tens is None else np.concatenate((tens, xyz), axis=2)
    
    # use mean distance from objects and k-means clustering to identify the two different views of each arrangement
    # format data
    X = np.concatenate((np.array(object_distance_mean_x).reshape(-1, 1), np.array(object_distance_mean_z).reshape(-1, 1)), axis=1)
    # print(X)
    
    # get labels and assign as cluster 1, invert for cluster 2
    cluster_1 = np.array(KMeans(n_clusters=2).fit(X).labels_, dtype=bool)
    cluster_2 = np.invert(cluster_1)
    pids = np.array(pids)
    cluster_pids.append(pids[cluster_1])
    cluster_pids.append(pids[cluster_2])
    # print(cluster_1)
    # print(cluster_2)
    
    # split tensors by clusters, append to final tensor array
    print(tens.shape)
    tensor_1 = np.array(tens[:, :, cluster_1], copy=True)
    tensor_1 = np.reshape(tensor_1, (tensor_1.shape[0], tensor_1.shape[1], tensor_1.shape[2], 1))
    tensor_2 = np.array(tens[:, :, cluster_2], copy=True)
    tensor_2 = np.reshape(tensor_2, (tensor_2.shape[0], tensor_2.shape[1], tensor_2.shape[2], 1))

    
    # project to 2d using average of participants' viewpoints per configuration view

    # 
    # print(config_table_pos)
    
    
    # define function to convert for each cluster/view
    def view_to_3d(mean_camera_pos, cluster, tensor, table_positions, obj1_positions):
        print(mean_camera_pos[cluster])
        camera_view = mean_camera_pos[cluster, :]
        obj1_pos = obj1_positions[cluster, :]
        # print(mean_view)
        table_positions = np.array(table_positions)
        table_positions = table_positions[cluster]
        table_2ds = []
        zero_2ds = []
        # print('table_positions', table_positions)
        # print(mean_view.shape)
        # print(mean_view)
        xy_full = None
        refs_1 = None
        points_1 = None
        view_ys = []
        print(tensor.shape[2])
        for i in range(tensor.shape[2]):
            point_matrix = np.copy(tensor[:, :, i]).reshape(-1, 3)
            
            # ax = plt.figure().add_subplot(projection='3d')
            # ax.plot(point_matrix.T[0, :], point_matrix.T[2, :], point_matrix.T[1, :], 'b.', alpha=0.5, markersize=1)
            # ax.set_ylim([-0.7, 0.3])
            # ax.set_xlim([0, 1])
            # ax.set_zlim([0.3, 1.3])
            # ax.set_title("before any changes")
            # plt.show()  
            
            view = camera_view[i, :]
            view_ref = np.array([view[0], 0, view[2]]).T
            view_ys.append(view[1])
            obj1_ref = obj1_pos[i, :]
            # print("view ref", view_ref)
            # print("point_matrix:", point_matrix[:3, :])
            # print("view:", view)
            # print('first points', point_matrix[:2, :])
            
            table_3d = np.array([table_positions[i][0], 0.7, table_positions[i][1]]).T
            zero_3d = np.array([0, 0, 0]).T
            v = table_3d - view
            norm = v / np.linalg.norm(v)
            # print('table_3d', table_3d)
            # print('norm', norm)
            
            # Perform Procrustes analysis to find the optimal transformation that aligns the two views
            refs = np.stack((table_3d, view_ref), axis=1).T
            if i == 0:
                refs_1 = refs
                refs_1_copy = np.array(refs_1)
                point_matrix = np.array(point_matrix.T, copy=True)
                points_copy = np.array(point_matrix, copy=True)
                
                # translate data to origin
                # print("refs1 before mean: ", refs_1)
                # ref1_mean = np.mean(refs_1, 0) 
                # print(refs_1.shape)
                point_matrix -= refs_1[0, :].reshape(-1, 1) 
                refs_1 -= refs_1[0, :]   # zero on tabletop centre
                view_ys[i] -= refs_1[0, 1]
                refs_1_meaned = np.array(refs_1)
                # print("refs1 after mean: ", refs_1)
                # print(point_matrix.shape)
                # print("points before mean", point_matrix[:, :3])
                
                # point_matrix -= np.mean(point_matrix, 0)
                # print("points after mean", point_matrix[:, :3])
                
                # change scaling of data (in rows) such that trace(mtx*mtx') = 1
                norm_1 = np.linalg.norm(refs_1)
                # print("norm 1" ,norm_1)
                refs_1 /= norm_1
                refs1_normed = np.array(refs_1)
                # point_matrix /= norm_1
                # print("refs 1 after norm divide:", refs_1)
                # print("point_matrix after norm divide:", point_matrix)
                 
                points_1 = np.array(point_matrix, copy=True)
                
                
                # ax = plt.figure().add_subplot(projection='3d')
                # ax.plot(points_copy[0, :], points_copy[2, :], points_copy[1, :], 'r.', alpha=0.5, markersize=1)
                # ax.plot(point_matrix[0, :], point_matrix[2, :], point_matrix[1, :], 'b.', alpha=0.5, markersize=1)
                # ax.set_ylim([-0.5, 0.5])
                # ax.set_xlim([-0.5, 0.5])
                # ax.set_zlim([0.3, 1.3])
                # plt.show()
                
            else:
                # the following taken from scipy procrustes function
                # translate all the data to the origin
                refs2_copy = np.array(refs)
                point_matrix = point_matrix.T
                point_matrix -= refs[0, :].reshape(-1, 1)
                refs -= refs[0, :]
                view_ys[i] -= refs[0, 1]
                refs2_meaned = np.array(refs)
                
                
                # ax = plt.figure().add_subplot(projection='3d')
                # ax.plot(points_1[0, :], points_1[2, :], points_1[1, :], 'r.', alpha=0.5, markersize=1)
                # ax.plot(point_matrix[0, :], point_matrix[2, :], point_matrix[1, :], 'b.', alpha=0.5, markersize=1)
                # ax.set_ylim([-0.7, 0.3])
                # ax.set_xlim([0, 1])
                # ax.set_zlim([0.3, 1.3])
                # ax.set_title("before second points changed")
                # plt.show()
                
                
                # point_matrix -= np.mean(point_matrix, 0)
                norm_2 = np.linalg.norm(refs)
                # change scaling of data (in rows) such that trace(mtx*mtx') = 1
                refs /= norm_2
                refs2_normed  = np.array(refs)
                # point_matrix /= norm_2
                
                

                if norm_1 == 0 or norm_2 == 0:
                    raise ValueError("Input matrices must contain >1 unique points")
                
                
                ax = plt.figure().add_subplot(projection='3d')
                ax.plot(points_1[0, :], points_1[2, :], points_1[1, :], 'r.', alpha=0.5, markersize=1)
                ax.plot(point_matrix[0, :], point_matrix[2, :], point_matrix[1, :], 'b.', alpha=0.5, markersize=1)
                ax.plot(refs_1_copy.T[0, :], refs_1_copy.T[2, :], refs_1_copy.T[1, :], 'rx', markersize=5, label='original')
                ax.plot(refs2_copy.T[0, :], refs2_copy.T[2, :], refs2_copy.T[1, :], 'bx', markersize=5, label='original')
                ax.plot(refs_1_meaned.T[0, :], refs_1_meaned.T[2, :], refs_1_meaned.T[1, :], 'ro',markersize=5, label='meaned')
                ax.plot(refs2_meaned.T[0, :], refs2_meaned.T[2, :], refs2_meaned.T[1, :], 'bo', markersize=5, label='meaned')
                ax.plot(refs1_normed.T[0, :], refs1_normed.T[2, :], refs1_normed.T[1, :], 'r^', markersize=7, label='normed')
                ax.plot(refs2_normed.T[0, :], refs2_normed.T[2, :], refs2_normed.T[1, :], 'go', markersize=5, label='normed')
                ax.set_ylim([-0.5, 0.5])
                ax.set_xlim([-0.5, 0.5])
                ax.set_zlim([-0.5, 0.5])
                ax.set_title("after second points zeroed and normed")
                ax.legend()
                plt.show()
                
                # get transformation of second matrix to minimize disparity
                R, s = orthogonal_procrustes(refs_1, refs)
                refs_trans = np.dot(refs, R.T) * s
                
                # ax = plt.figure().add_subplot(projection='3d')
                # ax.plot(points_1[0, :], points_1[2, :], points_1[1, :], 'r.', alpha=0.5, markersize=1)
                # ax.plot(point_matrix[0, :], point_matrix[2, :], point_matrix[1, :], 'b.', alpha=0.5, markersize=1)
                # ax.plot(refs1_normed.T[0, :], refs1_normed.T[2, :], refs1_normed.T[1, :], 'r^', markersize=7, label='normed')
                # ax.plot(refs_trans.T[0, :], refs_trans.T[2, :], refs_trans.T[1, :], 'go', markersize=5, label='transformed')
                # ax.set_ylim([-0.5, 0.5])
                # ax.set_xlim([-0.5, 0.5])
                # ax.set_zlim([0.3, 1.3])
                # ax.set_title("after second points zeroed and normed and ref transformed")
                # plt.show()
                
#                 ax = plt.figure().add_subplot(projection='3d')
#                 ax.plot(refs_1_copy.T[0, 0], refs_1_copy.T[2, 0], refs_1_copy.T[1, 0], 'rx', markersize=8, label='original')
#                 ax.plot(refs_1_copy.T[0, 1], refs_1_copy.T[2, 1], refs_1_copy.T[1, 1], 'ro', markersize=5, label='original')
#                 ax.plot(refs_1_meaned.T[0, 0], refs_1_meaned.T[2, 0], refs_1_meaned.T[1, 0], 'mx',markersize=8, label='meaned')
#                 ax.plot(refs_1_meaned.T[0, 1], refs_1_meaned.T[2, 1], refs_1_meaned.T[1, 1], 'mo', markersize=5, label='meaned')
#                 ax.plot(refs1_normed.T[0, 0], refs1_normed.T[2, 0], refs1_normed.T[1, 0], 'kx',markersize=8, label='normed')
#                 ax.plot(refs1_normed.T[0, 1], refs1_normed.T[2, 1], refs1_normed.T[1, 1], 'ko', markersize=5, label='normed')
                
#                 ax.plot(refs2_copy.T[0, 0], refs2_copy.T[2, 0], refs2_copy.T[1, 0], 'bx', markersize=8, label='original')
#                 ax.plot(refs2_copy.T[0, 1], refs2_copy.T[2, 1], refs2_copy.T[1, 1], 'bo', markersize=5, label='original')
#                 ax.plot(refs2_meaned.T[0, 0], refs2_meaned.T[2, 0], refs2_meaned.T[1, 0], 'cx',markersize=8, label='meaned')
#                 ax.plot(refs2_meaned.T[0, 1], refs2_meaned.T[2, 1], refs2_meaned.T[1, 1], 'co', markersize=5, label='meaned')
#                 ax.plot(refs2_normed.T[0, 0], refs2_normed.T[2, 0], refs2_normed.T[1, 0], 'gx',markersize=8, label='normed')
#                 ax.plot(refs2_normed.T[0, 1], refs1_normed.T[2, 1], refs2_normed.T[1, 1], 'go', markersize=5, label='normed')
                
#                 ax.plot(refs_trans.T[0, :], refs_trans.T[2, :], refs_trans.T[1, :], 'g^', markersize=5)
#                 ax.set_title("ref points")
#                 # ax.legend()
#                 plt.show()
                

                # # transform second matrix
                # # point_matrix *= s
                # print("R transposed", R.T.shape)
                # print("points shape", point_matrix.T.shape)
                # point_matrix = np.dot(point_matrix.T, R.T) # * s
                # print(point_matrix[:, :3])
                # point_matrix = point_matrix.T
                
                
                # ax = plt.figure().add_subplot(projection='3d')
                # ax.plot(points_1[0, :], points_1[2, :], points_1[1, :], 'r.', alpha=0.5, markersize=1)
                # ax.plot(point_matrix[0, :], point_matrix[2, :], point_matrix[1, :], 'b.', alpha=0.5, markersize=1)
                # ax.set_title("after procrustes")
                # ax.set_ylim([-0.7, 0.3])
                # ax.set_xlim([0, 1])
                # ax.set_zlim([0.3, 1.3])
                # plt.show()
                # mtx2 = np.dot(mtx2, R.T) * s
                
                # print(refs_1.shape)
                # print(refs.shape)
                # mtx1, mtx2, disparity = procrustes(refs_1, refs)
                # R, s = orthogonal_procrustes(refs_1, refs)
                # print(mtx1)
                # print(mtx2)
                # print("disparity:", disparity)
                # point_matrix = np.dot(point_matrix, mtx2['rotation']) * mtx2['scale'] + mtx2['translation']
                # table_3d = np.dot(table_3d, mtx2['rotation']) * mtx2['scale'] + mtx2['translation']
                # zero_3d = np.dot(zero_3d, mtx2['rotation']) * mtx2['scale'] + mtx2['translation']
            
            point_matrix = np.copy(point_matrix).T   # transpose back
            tensor[:, :, i] = point_matrix.reshape(-1, 3, 1)  # overwrite
        return tensor
#         # 2d projection - need extra help on this
#         view_y_mean = np.mean(view_ys)
#         view_y_mean = 0.8
#         view_mean = refs[1, :]
#         view_mean[1] = view_y_mean
#         print('refs 1', refs_1)
#         # view_mean = np.array([refs_1[1, 0], view_y_mean, refs_1[1, 1]]).T
#         # view_mean = np.array([0, view_y_mean, 0]).T
#         print('view_mean', view_mean)
#         v = refs_1[0, :] - view_mean
#         norm = v / np.linalg.norm(v)
        
#         for i in range(tensor.shape[2]):
#             point_matrix = np.copy(tensor[:, :, i]).reshape(-1, 3)
#             print('points shape', point_matrix.shape)
            
            
#             ax = plt.figure().add_subplot(projection='3d')
#             ax.plot(point_matrix.T[0, :], point_matrix.T[2, :], point_matrix.T[1, :], 'b.', alpha=0.5, markersize=1)
#             ax.plot(refs_1.T[0, :], refs_1.T[2, :], refs_1.T[1, :], 'g-', markersize=5, alpha=0.7, label='original')
#             ax.plot([refs_1[0, 0], view_mean[0]],[refs_1[0, 2], view_mean[2]],[refs_1[0, 1], view_mean[1]], 'r-', alpha=0.7)
#             # ax.plot(refs_1_meaned.T[0, :], refs_1_meaned.T[2, :], refs_1_meaned.T[1, :], 'ro',markersize=5, label='meaned')
#             # ax.plot(refs2_meaned.T[0, :], refs2_meaned.T[2, :], refs2_meaned.T[1, :], 'bo', markersize=5, label='meaned')
#             # ax.plot(refs1_normed.T[0, :], refs1_normed.T[2, :], refs1_normed.T[1, :], 'r^', markersize=7, label='normed')
#             # ax.plot(refs2_normed.T[0, :], refs2_normed.T[2, :], refs2_normed.T[1, :], 'go', markersize=5, label='normed')
#             ax.set_ylim([-0.5, 0.5])
#             ax.set_xlim([-0.5, 0.5])
#             ax.set_zlim([-0.5, 0.5])
#             ax.set_title("before projection")
#             ax.legend()
#             plt.show()
            
#             # # project to 2d coordinate space - NOT WORKING
#             # xy_3d = FixationProcessor.head_project(np.copy(point_matrix), head_loc_matrix=view_mean, output_dim='3d', use_headlocmat_as_mean=True, hard_mean_point=refs_1[0, :])
#             # refs_2d_3d = FixationProcessor.head_project(refs_1.T.reshape(-1, 3), head_loc_matrix=view, output_dim='3d', use_headlocmat_as_mean=True, hard_norm=norm)
#             # xy = FixationProcessor.head_project(np.copy(point_matrix), head_loc_matrix=view_mean, output_dim='2d', use_headlocmat_as_mean=True, hard_mean_point=refs_1[0, :])
#             # # refs_2d = FixationProcessor.head_project(refs_1.T.reshape(-1, 3), head_loc_matrix=view, output_dim='2d', use_headlocmat_as_mean=True, hard_norm=norm)
#             # print(xy.shape)
#             # ax2d = plt.figure().add_subplot()
#             # ax2d.plot(xy[:, 0], xy[:, 1], 'r.', alpha=0.5, markersize=1)
#             # # ax.plot(refs_2d[0, 0], refs_2d[0, 1], 'bx', markersize=5)
#             # # ax.plot(refs_2d[1, 0], refs_2d[1, 1], 'gx', markersize=5)
#             # ax2d.set_xlim([-0.5, 0.5])
#             # ax2d.set_ylim([-0.5, 0.5])
#             # # ax.set_zlim([-0.5, 0.5])
#             # plt.show()

                               
#             # plot debug
#             # ax3dfull = plt.figure().add_subplot(projection="3d")
#             # ax3dfull.plot(point_matrix[:, 0], point_matrix[:, 2], point_matrix[:, 1], 'r.', alpha=0.5, markersize=1)
#             # # ax3dfull.plot(refs_2d_3d[0, 0], refs_2d_3d[0, 2], refs_2d_3d[0, 1], 'bx', markersize=5)
#             # # ax3dfull.plot(refs_2d_3d[1, 0], refs_2d_3d[1, 2], refs_2d_3d[1, 1], 'gx', markersize=5)
#             # ax3dfull.set_xlim([-0.5, 0.5])
#             # ax3dfull.set_ylim([-0.5, 0.5])
#             # ax3dfull.set_zlim([-0.5, 0.5])
#             # ax3dfull.set_zlim([0.3, 1.3])
            
#             # plt.show()
            
#             # ax3d = plt.figure().add_subplot(projection="3d")
#             # ax3d.plot(xy_3d[:, 0], xy_3d[:, 2], xy_3d[:, 1], 'r.', alpha=0.5, markersize=1)
#             # ax3d.plot(view_mean[0], view_mean[2], view_mean[1], 'bx', markersize=5)
#             # # ax3d.plot(refs_2d_3d[1, 0], refs_2d_3d[1, 2], refs_2d_3d[1, 1], 'gx', markersize=5)          
#             # ax3d.set_xlim([-0.5, 0.5])
#             # ax3d.set_ylim([-0.5, 0.5])
#             # ax3d.set_zlim([-0.5, 0.5])
#             # plt.show()
            
            
#             print('xy points after:', xy[:3, :])
#             print('xy shape:', xy.shape)
#             xy = np.reshape(xy, (-1, 2, 1))
#             xy_full = xy if xy_full is None else np.concatenate((xy_full, xy), axis=2)
#         return np.reshape(xy_full, (xy_full.shape[0], xy_full.shape[1], xy_full.shape[2], 1))
        # return None
    
    
#     for i in range(tensor_1.shape[2]):
#         point_matrix = np.copy(tensor_1[:, :, i]).reshape(-1, 3)

#         ax = plt.figure().add_subplot(projection='3d')
#         ax.plot(point_matrix.T[0, :], point_matrix.T[2, :], point_matrix.T[1, :], 'g.', alpha=0.5, markersize=1)
#         ax.set_ylim([-0.7, 0.3])
#         ax.set_xlim([0, 1])
#         ax.set_zlim([0.3, 1.3])
#         ax.set_title("before function (tensor_1)")
#         plt.show()  
    
    # add to overall array
    # convert to numpy for cluster indexing
    mean_camera_pos = np.array(mean_camera_pos).reshape(-1, 3)
    config_obj1_pos = np.array(config_obj1_pos).reshape(-1, 3)
    # xy_1 = view_to_3d(mean_camera_pos, cluster_1, np.copy(tensor_1), config_table_pos, config_obj1_pos)
    # xy_2 = view_to_3d(mean_camera_pos, cluster_2, np.copy(tensor_2), config_table_pos, config_obj1_pos)
    # Ms = xy_1 if Ms is None else np.concatenate((Ms, xy_1), axis=3)
    # Ms = np.concatenate((Ms, xy_2), axis=3)
    tensor_1 = view_to_3d(mean_camera_pos, cluster_1, np.copy(tensor_1), config_table_pos, config_obj1_pos)
    tensor_2 = view_to_3d(mean_camera_pos, cluster_2, np.copy(tensor_2), config_table_pos, config_obj1_pos)
    Ts_normed.append(tensor_1)
    Ts_normed.append(tensor_2)
    
    
    
# print(Ms.shape)
# Out:
# dataframe returned in 0.0653994083404541
# dataframe returned in 0.04252290725708008
# dataframe returned in 0.0679464340209961
# dataframe returned in 0.0401151180267334
# dataframe returned in 0.0507962703704834
# dataframe returned in 0.050992488861083984
# dataframe returned in 0.1287539005279541
# dataframe returned in 0.049785614013671875
# dataframe returned in 0.05260896682739258
# dataframe returned in 0.08825421333312988
# dataframe returned in 0.055893659591674805
# dataframe returned in 0.05124497413635254
# dataframe returned in 0.041889190673828125
# dataframe returned in 0.047653913497924805
# dataframe returned in 0.05444931983947754
# (467, 3, 15)
# [[-0.54506231  1.49999334  0.59835832]
#  [-1.094056    1.31289746 -0.2081012 ]
#  [-0.6105412   1.68433143  0.67826522]
#  [ 0.56781569  1.50260184  0.78206641]
#  [-0.70434345  1.56717999 -0.72474521]
#  [-0.80254558  1.45709029  0.68614111]
#  [-0.96462239  1.62158533 -0.31027006]
#  [-0.74575188  1.53180655 -0.25438252]
#  [-0.69002287  1.49342707  0.60226494]
#  [-0.54389747  1.5066017   0.61952076]
#  [-0.75355546  1.23565299  0.65144776]]
# 11
# C:\Users\Luke\anaconda3\envs\alloeyepy\lib\site-packages\ipywidgets\widgets\widget.py:502: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super().__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# C:\Users\Luke\AppData\Local\Temp\ipykernel_6396\2485198240.py:264: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   ax = plt.figure().add_subplot(projection='3d')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# [[ 0.61700569  1.50772111 -0.69581651]
#  [ 0.64315988  1.48401133 -0.59705825]
#  [ 0.74904544  1.49447351 -0.78511695]
#  [ 0.63681006  1.70178925 -0.64005978]]
# 4
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.array([4.14298868, 4.14306703, 4.14228124]) - 0.7490454411885245
# Out:
# array([3.39394324, 3.39402159, 3.3932358 ])

# %%
colors = itertools.cycle(["r", "b", "g", "c", "m", "k"])
for t in range(len(Ts_normed)):
    ax = plt.figure().add_subplot(projection='3d')
    # print(Ts_normed)
    tensor = Ts_normed[t]
    print(tensor.shape)
    for i in range(tensor.shape[2]):
        # print(i)
        color = next(colors)
        # print(color)
        x = tensor[:, 0, i].flatten()
        y = tensor[:, 2, i].flatten()
        z = tensor[:, 1, i].flatten()
        # print(x)

        ax.plot(x, y, z, '.', c=color, alpha=0.5, markersize=1)
    plt.show()
    ax.set_xlim([-0.5, 0.5])
    ax.set_zlim([-0.5, 0.5])
    ax.set_ylim([-0.5, 0.5])
# Out:
# (467, 3, 11, 1)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (467, 3, 4, 1)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# colors = itertools.cycle(["r", "b", "g", "c", "m", "k"])
# for t in range(Ms.shape[-1]):
#     ax = plt.figure().add_subplot()
#     tensor = Ms[:,:,:,t]
    
#     for i in range(tensor.shape[2]):
#         print(i)
#         color = next(colors)
#         print(color)
#         x = tensor[:, 0, i]
#         y = tensor[:, 1, i]   

#         ax.plot(x, y, '.', c=color, alpha=0.5, markersize=1)
#     plt.show()
#     ax.set_xlim([-0.5, 0.5])
#     # # ax.set_zlim([0.2, 1.3])
#     ax.set_ylim([-0.5, 0.5])

# %%
Ts_normed.shape

# %%
from scipy.ndimage import gaussian_filter

def create_3d_probability_map(data, time_window_size=100, gaussian_sigma=None):
    """
    Creates multiple probability maps over time for 3D spatial data.

    Parameters:
    data (ndarray): 3D spatial data over time of shape (n_points_over_time, spatial dimension, participant).
    time_window_size (int): Time window size in ms for each probability map. Default is 100ms.
    gaussian_sigma (float or sequence of floats): Standard deviation for Gaussian smoothing. Default is None.

    Returns:
    ndarray: Probability maps over time of shape (n_time_windows, spatial dimension).
    """
    n_points_over_time, spatial_dim, n_participants = data.shape
    time_window_step = time_window_size // 2

    # Calculate number of time windows
    n_time_windows = int(np.ceil(n_points_over_time / time_window_step))

    # Create empty array for probability maps
    probability_maps = np.zeros((n_time_windows, spatial_dim))

    # Iterate over time windows
    for i in range(n_time_windows):
        start_index = i * time_window_step
        end_index = min(start_index + time_window_size, n_points_over_time)
        
        bin_data = data[start_index:end_index, :, :]
        print(bin_data.shape)

        # Extract spatial data for each participant and concatenate along participant axis
        spatial_data = np.concatenate([data[start_index:end_index, :, p] for p in range(n_participants)], axis=0)
        print(spatial_data.shape)
        print(spatial_data[:5, :])

        # Optionally apply Gaussian smoothing
        if gaussian_sigma is not None:
            spatial_data = gaussian_filter(spatial_data, sigma=gaussian_sigma)

        # Calculate probability map by averaging over participants
        print(spatial_data.shape)
        print(spatial_data[:5, :])
        probability_map = np.mean(spatial_data, axis=-1)
        print(probability_map.shape)

        # Add probability map to array
        probability_maps[i, :] = probability_map

    return probability_maps



def create_3d_gaussian_prob_map(points_by_ppt, voxel_size=0.01, sigma=5, bounds=0.5, plot=False):
    # get n ppts
    n_ppts = points_by_ppt.shape[2]
    
    # Calculate the maximum and minimum x, y, and z coordinates of the points
    max_x, max_y, max_z = bounds, bounds, bounds
    min_x, min_y, min_z = -bounds, -bounds, -bounds

    # Calculate the dimensions of the bounding box
    dim_x = int((max_x - min_x) / voxel_size) + 1
    dim_y = int((max_y - min_y) / voxel_size) + 1
    dim_z = int((max_z - min_z) / voxel_size) + 1
    
    # Create a 3D grid
    xv, yv, zv = np.meshgrid(np.linspace(min_x, max_x, dim_x), 
                              np.linspace(min_y, max_y, dim_y),
                              np.linspace(min_z, max_z, dim_z), indexing='ij')
    voxel_centers = np.column_stack((xv.ravel(), yv.ravel(), zv.ravel()))
    
    # grid = np.mgrid[min_x:max_x+voxel_size:voxel_size]
    print(x.shape)
    voxel_counts = np.zeros_like(xv)
    voxel_counts_agg = np.zeros_like(voxel_counts)
    # Create an empty 3D array to represent the probability map
    prob_map = np.zeros((dim_x, dim_y, dim_z))

    # Convert the point coordinates to voxel coordinates
    for p in range(n_ppts):
        points = points_by_ppt[:, :, p]
        # points = points.clip(min=-bounds, max=bounds)
        mask = (points[:, 0] >= min_x) & (points[:, 0] <= max_x) & \
               (points[:, 1] >= min_y) & (points[:, 1] <= max_y) & \
               (points[:, 2] >= min_z) & (points[:, 2] <= max_z)
        points = points[mask]
        # print('clipped',points[100:105, :])
        a = points - [min_x, min_y, min_z]
        # print('a',a[100:105,:])
        # ax = plt.figure().add_subplot(projection='3d')
        # ax.plot(points[:,0], points[:, 2], points[:, 1], 'r.', markersize=1, alpha=0.4)
        # ax.set_xlim([-0.5, 0.5])
        # ax.set_zlim([-0.5, 0.5])
        # ax.set_ylim([-0.5, 0.5])
        # plt.show()
        b = (a / voxel_size).astype(int)
        # print('b', b[100:105,:])
        voxel_coords = b
        # print(voxel_coords)
        for i, j, k in voxel_coords:
            voxel_counts[i,j,k] += 1
        voxel_counts /= np.sum(voxel_counts)  # convert to probability per participant
        print(np.sum(voxel_counts))
    
    prob_map += voxel_counts / n_ppts
    # print(voxel_counts_agg)


    # Apply Gaussian smoothing to the probability map
    prob_map = gaussian_filter(prob_map, sigma=sigma)

#     # Normalize the probability map so that it sums to 1
    prob_map /= np.sum(prob_map)
#     print(prob_map_smooth.shape)
    
    if plot:
        plot_3d_probability_distribution(prob_map, voxel_centers)

    return prob_map, voxel_centers

# assuming your data is in a variable called 'data'
for c in range(len(Ts_normed)):
    data = Ts_normed[c]
    data = data.reshape(data.shape[0], data.shape[1], data.shape[2])
    # print(data[:3, 0, :] )
    print(data.shape)
    prob_map, voxel_centers = create_3d_gaussian_prob_map(data, plot=False)
    pid = np.array(cluster_pids)[c][0]
    tps = fetch_timepoints(pid, ret_epochs=['na'], configurations = [config], suppress_print=True)
    viewing_plot(tps, prob_map=prob_map, pmap_voxel_centers=voxel_centers)
# prob_map = create_3d_probability_map(data, time_window_size=90, gaussian_sigma=5)
# Out:
# (467, 3, 11)
# (467,)
# 1.0
# 1.0
# 1.0000000000000002
# 0.9999999999999997
# 1.0000000000000002
# 0.9999999999999997
# 0.9999999999999998
# 1.0
# 1.0000000000000002
# 1.0
# 0.9999999999999997
# C:\Users\Luke\AppData\Local\Temp\ipykernel_6396\482968344.py:129: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   pid = np.array(cluster_pids)[c][0]
# dataframe returned in 0.08975934982299805
# ['5Ball' 'Crown' 'Cup' 'Truck']
# min:  1.0000027224036914e-05 max:  0.0002181240432636516
# C:\Users\Luke\anaconda3\envs\alloeyepy\lib\site-packages\ipywidgets\widgets\widget.py:502: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super().__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (467, 3, 4)
# (467,)
# 0.9999999999999999
# 0.9999999999999993
# 1.0
# 1.0
# C:\Users\Luke\AppData\Local\Temp\ipykernel_6396\482968344.py:129: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   pid = np.array(cluster_pids)[c][0]
# C:\Users\Luke\anaconda3\envs\alloeyepy\lib\site-packages\ipywidgets\widgets\widget.py:502: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super().__init__(**kwargs)
# dataframe returned in 0.058458566665649414
# ['Helmet' 'Lemon' 'Tape' 'Tomato']
# min:  1.0000963360161443e-05 max:  0.00018972681678996979
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
## next steps

# problems to solve
# 1. 2d projection not quite overlaid - for one cluster, this is partly because the viewpoint positions are very different. For all of them, the norm when projecting to 2d will be different because it will be from the mean of the gaze points for that participant. 
# fix ideas: for all points from the same view and viewpoint (see below), project to 2d together and separate after;
#      using clustering or calculating distance, check whether viewpoints are similar enough to just take the mean, or split into two viewpoints (of the same view)
#           if splitting into two viewpoints, can then project to 2d separately (see above)
#      however, will need to re-normalize still. One idea could be to use an object (e.g. obj1, or mean of object locations) as a reference point that is projected to 2d and correct for difference in 2d position
#      can use one participant's obj1 2d position as reference, and simply add the difference between that and each other participants' obj1 2d position to those participants' gaze points
#      

# average tensors across participants for each time point - 3D proportional looking (heatmap)
    # might need to choose a 'voxel' size - look up methods for this
# smooth with Guassian kernel (accounting for time somehow)
# visualise these data with animated 3D plots - 3 spatial dimensions + time
