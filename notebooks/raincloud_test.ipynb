# %%
import seaborn as sns
import matplotlib.pyplot as plt
import ptitprince as pt
import pandas as pd
import numpy as np

# %%
# For simplicity, let's create some random data
df = pd.DataFrame({
    "value": np.random.normal(size=300),
    "group": np.repeat(['A', 'B', 'C'], 100)
})

# %%
# Initialize figure and ax
f, ax = plt.subplots(figsize=(7, 5))

# Create the raincloud plot
pt.RainCloud(x="group", y="value", data=df, palette="Set2", bw=.2,
             width_viol=.6, ax=ax, orient='h', pointplot=True)

# Show the plot
plt.show()

# %%
all_real_trials = pd.read_csv('C:\\Users\\Luke\\Documents\\AlloEye\\data\\feature_saves\\all_real_trials.csv')
print(all_real_trials.shape)
# Out:
# (3977, 173)
